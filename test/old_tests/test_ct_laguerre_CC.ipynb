# %%
from architectures_v1 import *
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, RNN
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

import os
import numpy as np
import tensorflow as tf
import pandas as pd
import time

# %% [markdown]
# ## Loading Training/Testing/Validation Data

# %%
dataset = "ChlorineConcentration"

x_train_load = np.load(os.path.abspath(os.path.join('99_data', dataset,'x_train.npz')))
x_test_load = np.load(os.path.abspath(os.path.join('99_data', dataset,'x_test.npz')))

x_train = np.reshape(x_train_load['arr_0'], [x_train_load['arr_0'].shape[0], x_train_load['arr_0'].shape[1], 1])
x_test = np.reshape(x_test_load['arr_0'], [x_test_load['arr_0'].shape[0], x_test_load['arr_0'].shape[1], 1])

x_all = np.concatenate((x_train, x_test), axis = 0)

n_instances = x_all.shape[0]

y_train_load = np.load(os.path.abspath(os.path.join('99_data', dataset,'y_train.npz')))
y_test_load = np.load(os.path.abspath(os.path.join('99_data', dataset,'y_test.npz')))

y_train = y_train_load['arr_0']
y_test = y_test_load['arr_0']

y_all = np.concatenate((y_train, y_test), axis = 0)

x_train, x_test, y_train, y_test = train_test_split(x_all, y_all, test_size = 0.3, random_state = 42)

x_valid = x_test[:int(0.1*n_instances), :, :]
y_valid = y_test[:int(0.1*n_instances)]

x_test = x_test[int(0.1*n_instances):, :, :]
y_test = y_test[int(0.1*n_instances):]

print(f"x_train: {x_train.shape} - y_train: {y_train.shape}")
print(f"x_test: {x_test.shape} - y_test: {y_test.shape}")
print(f"x_valid: {x_valid.shape} - y_valid: {y_valid.shape}")
# Out:
# x_train: (3014, 166, 1) - y_train: (3014,)
# x_test: (863, 166, 1) - y_test: (863,)
# x_valid: (430, 166, 1) - y_valid: (430,)

# %%
seed = 42
tf.random.set_random_seed(seed)
np.random.seed(seed)

length = x_train.shape[1]
n_features = x_train.shape[-1]

model = Sequential()

model.add(RNN(OrthogonalCell(units = 212,
                             order = 50,
                             variant = 'ct_laguerre',
                             dt = 1,
                            input_dims = 1), 
              input_shape = (length, n_features),
             return_sequences = False))
model.add(Dense(to_categorical(y_train).shape[-1], activation = "softmax"))

model.compile(optimizer = "adam", loss = "categorical_crossentropy", metrics = ["accuracy"])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rnn_1 (RNN)                  (None, 212)               58571
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 852
# =================================================================
# Total params: 59,423
# Trainable params: 56,871
# Non-trainable params: 2,552
# _________________________________________________________________

# %%
if not os.path.exists(os.path.abspath(os.path.join('models', dataset))):
    os.mkdir(os.path.abspath(os.path.join('models', dataset)))

file_path = os.path.abspath(os.path.join('models', dataset, f'{dataset}-laguerre.hdf5'))

callbacks = [
    ModelCheckpoint(filepath=file_path, monitor='val_loss', save_best_only = True, mode = 'min', verbose = 1), 
    EarlyStopping(monitor = 'val_loss', patience = 10, mode = 'min')]

t = time.time()

result = model.fit(x_train, 
                   to_categorical(y_train),
                   epochs = 200, 
                   batch_size = 100, 
                   validation_data = (x_valid, to_categorical(y_valid)), 
                   callbacks = callbacks)

print(f"Training time: {time.time() - t} s")

df_results = pd.DataFrame(result.history)
df_results.to_csv(os.path.abspath(os.path.join('models', dataset, 'laguerre_results.csv')))
# Out:
# Train on 3014 samples, validate on 430 samples
# Epoch 1/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 1.0441 - acc: 0.5290
# Epoch 00001: val_loss improved from inf to 1.00791, saving model to /Users/sergio.dorado/Documents/GitHub_Repositories/01_Maintained/NeuralODE/models/ChlorineConcentration/ChlorineConcentration-laguerre.hdf5
# 3014/3014 [==============================] - 4s 1ms/sample - loss: 1.0448 - acc: 0.5279 - val_loss: 1.0079 - val_acc: 0.5977
# Epoch 2/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.9937 - acc: 0.5453
# Epoch 00002: val_loss improved from 1.00791 to 0.92227, saving model to /Users/sergio.dorado/Documents/GitHub_Repositories/01_Maintained/NeuralODE/models/ChlorineConcentration/ChlorineConcentration-laguerre.hdf5
# 3014/3014 [==============================] - 4s 1ms/sample - loss: 0.9934 - acc: 0.5455 - val_loss: 0.9223 - val_acc: 0.5977
# Epoch 3/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.9734 - acc: 0.5567
# Epoch 00003: val_loss did not improve from 0.92227
# 3014/3014 [==============================] - 4s 1ms/sample - loss: 0.9738 - acc: 0.5561 - val_loss: 0.9749 - val_acc: 0.6000
# Epoch 4/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.9705 - acc: 0.5623
# Epoch 00004: val_loss did not improve from 0.92227
# 3014/3014 [==============================] - 4s 1ms/sample - loss: 0.9716 - acc: 0.5617 - val_loss: 0.9311 - val_acc: 0.6000
# Epoch 5/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.9625 - acc: 0.5603
# Epoch 00005: val_loss improved from 0.92227 to 0.91164, saving model to /Users/sergio.dorado/Documents/GitHub_Repositories/01_Maintained/NeuralODE/models/ChlorineConcentration/ChlorineConcentration-laguerre.hdf5
# 3014/3014 [==============================] - 4s 1ms/sample - loss: 0.9627 - acc: 0.5601 - val_loss: 0.9116 - val_acc: 0.6000
# Epoch 6/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.9356 - acc: 0.5673
# Epoch 00006: val_loss improved from 0.91164 to 0.91119, saving model to /Users/sergio.dorado/Documents/GitHub_Repositories/01_Maintained/NeuralODE/models/ChlorineConcentration/ChlorineConcentration-laguerre.hdf5
# 3014/3014 [==============================] - 4s 1ms/sample - loss: 0.9366 - acc: 0.5667 - val_loss: 0.9112 - val_acc: 0.5953
# Epoch 7/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.9381 - acc: 0.5713
# Epoch 00007: val_loss did not improve from 0.91119
# 3014/3014 [==============================] - 4s 1ms/sample - loss: 0.9385 - acc: 0.5703 - val_loss: 0.9639 - val_acc: 0.5442
# Epoch 8/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.9505 - acc: 0.5660
# Epoch 00008: val_loss did not improve from 0.91119
# 3014/3014 [==============================] - 4s 1ms/sample - loss: 0.9505 - acc: 0.5660 - val_loss: 0.9331 - val_acc: 0.5558
# Epoch 9/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.9479 - acc: 0.5657
# Epoch 00009: val_loss did not improve from 0.91119
# 3014/3014 [==============================] - 4s 1ms/sample - loss: 0.9481 - acc: 0.5654 - val_loss: 0.9147 - val_acc: 0.6023
# Epoch 10/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.9442 - acc: 0.5587
# Epoch 00010: val_loss improved from 0.91119 to 0.88997, saving model to /Users/sergio.dorado/Documents/GitHub_Repositories/01_Maintained/NeuralODE/models/ChlorineConcentration/ChlorineConcentration-laguerre.hdf5
# 3014/3014 [==============================] - 4s 1ms/sample - loss: 0.9446 - acc: 0.5587 - val_loss: 0.8900 - val_acc: 0.5930
# Epoch 11/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.9310 - acc: 0.5737
# Epoch 00011: val_loss did not improve from 0.88997
# 3014/3014 [==============================] - 4s 1ms/sample - loss: 0.9301 - acc: 0.5743 - val_loss: 0.9281 - val_acc: 0.5953
# Epoch 12/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.9117 - acc: 0.5647
# Epoch 00012: val_loss did not improve from 0.88997
# 3014/3014 [==============================] - 4s 1ms/sample - loss: 0.9117 - acc: 0.5647 - val_loss: 0.9063 - val_acc: 0.6070
# Epoch 13/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.9108 - acc: 0.5720
# Epoch 00013: val_loss did not improve from 0.88997
# 3014/3014 [==============================] - 4s 1ms/sample - loss: 0.9099 - acc: 0.5730 - val_loss: 0.8995 - val_acc: 0.5930
# Epoch 14/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.9264 - acc: 0.5710
# Epoch 00014: val_loss improved from 0.88997 to 0.86753, saving model to /Users/sergio.dorado/Documents/GitHub_Repositories/01_Maintained/NeuralODE/models/ChlorineConcentration/ChlorineConcentration-laguerre.hdf5
# 3014/3014 [==============================] - 4s 1ms/sample - loss: 0.9265 - acc: 0.5707 - val_loss: 0.8675 - val_acc: 0.5907
# Epoch 15/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.9109 - acc: 0.5693
# Epoch 00015: val_loss did not improve from 0.86753
# 3014/3014 [==============================] - 5s 2ms/sample - loss: 0.9119 - acc: 0.5683 - val_loss: 0.8918 - val_acc: 0.6023
# Epoch 16/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.9073 - acc: 0.5737
# Epoch 00016: val_loss did not improve from 0.86753
# 3014/3014 [==============================] - 5s 2ms/sample - loss: 0.9076 - acc: 0.5733 - val_loss: 0.8849 - val_acc: 0.5860
# Epoch 17/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.9140 - acc: 0.5753
# Epoch 00017: val_loss did not improve from 0.86753
# 3014/3014 [==============================] - 5s 2ms/sample - loss: 0.9139 - acc: 0.5756 - val_loss: 0.9922 - val_acc: 0.5070
# Epoch 18/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.9225 - acc: 0.5717
# Epoch 00018: val_loss did not improve from 0.86753
# 3014/3014 [==============================] - 5s 2ms/sample - loss: 0.9229 - acc: 0.5710 - val_loss: 0.9001 - val_acc: 0.5930
# Epoch 19/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.8844 - acc: 0.5770
# Epoch 00019: val_loss did not improve from 0.86753
# 3014/3014 [==============================] - 5s 2ms/sample - loss: 0.8843 - acc: 0.5773 - val_loss: 0.8979 - val_acc: 0.5535
# Epoch 20/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.9113 - acc: 0.5713
# Epoch 00020: val_loss did not improve from 0.86753
# 3014/3014 [==============================] - 5s 2ms/sample - loss: 0.9119 - acc: 0.5707 - val_loss: 0.9554 - val_acc: 0.5209
# Epoch 21/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.9069 - acc: 0.5693
# Epoch 00021: val_loss did not improve from 0.86753
# 3014/3014 [==============================] - 5s 2ms/sample - loss: 0.9077 - acc: 0.5687 - val_loss: 0.8710 - val_acc: 0.6140
# Epoch 22/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.8984 - acc: 0.5667
# Epoch 00022: val_loss did not improve from 0.86753
# 3014/3014 [==============================] - 5s 2ms/sample - loss: 0.8990 - acc: 0.5660 - val_loss: 0.8891 - val_acc: 0.6093
# Epoch 23/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.9026 - acc: 0.5773
# Epoch 00023: val_loss improved from 0.86753 to 0.85933, saving model to /Users/sergio.dorado/Documents/GitHub_Repositories/01_Maintained/NeuralODE/models/ChlorineConcentration/ChlorineConcentration-laguerre.hdf5
# 3014/3014 [==============================] - 5s 2ms/sample - loss: 0.9016 - acc: 0.5783 - val_loss: 0.8593 - val_acc: 0.5930
# Epoch 24/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.8789 - acc: 0.5703
# Epoch 00024: val_loss did not improve from 0.85933
# 3014/3014 [==============================] - 5s 2ms/sample - loss: 0.8791 - acc: 0.5700 - val_loss: 0.8876 - val_acc: 0.5930
# Epoch 25/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.8966 - acc: 0.5713
# Epoch 00025: val_loss did not improve from 0.85933
# 3014/3014 [==============================] - 5s 2ms/sample - loss: 0.8972 - acc: 0.5703 - val_loss: 1.0708 - val_acc: 0.4698
# Epoch 26/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.9090 - acc: 0.5633
# Epoch 00026: val_loss did not improve from 0.85933
# 3014/3014 [==============================] - 5s 2ms/sample - loss: 0.9067 - acc: 0.5650 - val_loss: 0.9463 - val_acc: 0.6116
# Epoch 27/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.8827 - acc: 0.5857
# Epoch 00027: val_loss did not improve from 0.85933
# 3014/3014 [==============================] - 5s 2ms/sample - loss: 0.8836 - acc: 0.5849 - val_loss: 0.8994 - val_acc: 0.5628
# Epoch 28/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.8713 - acc: 0.5750
# Epoch 00028: val_loss did not improve from 0.85933
# 3014/3014 [==============================] - 5s 2ms/sample - loss: 0.8714 - acc: 0.5750 - val_loss: 0.9999 - val_acc: 0.4860
# Epoch 29/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.9480 - acc: 0.5620
# Epoch 00029: val_loss did not improve from 0.85933
# 3014/3014 [==============================] - 5s 2ms/sample - loss: 0.9478 - acc: 0.5627 - val_loss: 0.8995 - val_acc: 0.6209
# Epoch 30/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.9145 - acc: 0.5870
# Epoch 00030: val_loss did not improve from 0.85933
# 3014/3014 [==============================] - 5s 2ms/sample - loss: 0.9143 - acc: 0.5866 - val_loss: 0.8895 - val_acc: 0.5837
# Epoch 31/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.8697 - acc: 0.5787
# Epoch 00031: val_loss did not improve from 0.85933
# 3014/3014 [==============================] - 5s 2ms/sample - loss: 0.8703 - acc: 0.5780 - val_loss: 0.8747 - val_acc: 0.5721
# Epoch 32/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.8465 - acc: 0.5787
# Epoch 00032: val_loss improved from 0.85933 to 0.81142, saving model to /Users/sergio.dorado/Documents/GitHub_Repositories/01_Maintained/NeuralODE/models/ChlorineConcentration/ChlorineConcentration-laguerre.hdf5
# 3014/3014 [==============================] - 5s 2ms/sample - loss: 0.8462 - acc: 0.5790 - val_loss: 0.8114 - val_acc: 0.6140
# Epoch 33/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.8029 - acc: 0.6113
# Epoch 00033: val_loss did not improve from 0.81142
# 3014/3014 [==============================] - 5s 2ms/sample - loss: 0.8036 - acc: 0.6102 - val_loss: 0.8828 - val_acc: 0.5651
# Epoch 34/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.8883 - acc: 0.5827
# Epoch 00034: val_loss did not improve from 0.81142
# 3014/3014 [==============================] - 5s 2ms/sample - loss: 0.8869 - acc: 0.5833 - val_loss: 0.8642 - val_acc: 0.5930
# Epoch 35/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.8258 - acc: 0.5977
# Epoch 00035: val_loss did not improve from 0.81142
# 3014/3014 [==============================] - 5s 2ms/sample - loss: 0.8263 - acc: 0.5972 - val_loss: 0.9717 - val_acc: 0.6000
# Epoch 36/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.8361 - acc: 0.6020
# Epoch 00036: val_loss did not improve from 0.81142
# 3014/3014 [==============================] - 5s 2ms/sample - loss: 0.8347 - acc: 0.6032 - val_loss: 0.8182 - val_acc: 0.5605
# Epoch 37/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.7956 - acc: 0.6167
# Epoch 00037: val_loss did not improve from 0.81142
# 3014/3014 [==============================] - 5s 2ms/sample - loss: 0.7947 - acc: 0.6178 - val_loss: 0.9089 - val_acc: 0.5628
# Epoch 38/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.7811 - acc: 0.6233
# Epoch 00038: val_loss improved from 0.81142 to 0.72017, saving model to /Users/sergio.dorado/Documents/GitHub_Repositories/01_Maintained/NeuralODE/models/ChlorineConcentration/ChlorineConcentration-laguerre.hdf5
# 3014/3014 [==============================] - 6s 2ms/sample - loss: 0.7804 - acc: 0.6241 - val_loss: 0.7202 - val_acc: 0.6930
# Epoch 39/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.7118 - acc: 0.6653
# Epoch 00039: val_loss did not improve from 0.72017
# 3014/3014 [==============================] - 5s 2ms/sample - loss: 0.7120 - acc: 0.6656 - val_loss: 0.7791 - val_acc: 0.6628
# Epoch 40/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.7962 - acc: 0.6263
# Epoch 00040: val_loss did not improve from 0.72017
# 3014/3014 [==============================] - 5s 2ms/sample - loss: 0.7950 - acc: 0.6274 - val_loss: 0.8088 - val_acc: 0.6093
# Epoch 41/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.6901 - acc: 0.6773
# Epoch 00041: val_loss improved from 0.72017 to 0.65473, saving model to /Users/sergio.dorado/Documents/GitHub_Repositories/01_Maintained/NeuralODE/models/ChlorineConcentration/ChlorineConcentration-laguerre.hdf5
# 3014/3014 [==============================] - 6s 2ms/sample - loss: 0.6899 - acc: 0.6768 - val_loss: 0.6547 - val_acc: 0.7163
# Epoch 42/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.6429 - acc: 0.6957
# Epoch 00042: val_loss did not improve from 0.65473
# 3014/3014 [==============================] - 6s 2ms/sample - loss: 0.6420 - acc: 0.6958 - val_loss: 0.7252 - val_acc: 0.6581
# Epoch 43/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.6140 - acc: 0.7207
# Epoch 00043: val_loss did not improve from 0.65473
# 3014/3014 [==============================] - 6s 2ms/sample - loss: 0.6142 - acc: 0.7213 - val_loss: 0.7105 - val_acc: 0.6535
# Epoch 44/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.5922 - acc: 0.7307
# Epoch 00044: val_loss improved from 0.65473 to 0.59646, saving model to /Users/sergio.dorado/Documents/GitHub_Repositories/01_Maintained/NeuralODE/models/ChlorineConcentration/ChlorineConcentration-laguerre.hdf5
# 3014/3014 [==============================] - 6s 2ms/sample - loss: 0.5918 - acc: 0.7306 - val_loss: 0.5965 - val_acc: 0.7349
# Epoch 45/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.6249 - acc: 0.7103
# Epoch 00045: val_loss did not improve from 0.59646
# 3014/3014 [==============================] - 6s 2ms/sample - loss: 0.6242 - acc: 0.7110 - val_loss: 0.6739 - val_acc: 0.6326
# Epoch 46/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.6345 - acc: 0.7103
# Epoch 00046: val_loss did not improve from 0.59646
# 3014/3014 [==============================] - 6s 2ms/sample - loss: 0.6348 - acc: 0.7100 - val_loss: 0.7157 - val_acc: 0.6791
# Epoch 47/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.5516 - acc: 0.7550
# Epoch 00047: val_loss did not improve from 0.59646
# 3014/3014 [==============================] - 6s 2ms/sample - loss: 0.5527 - acc: 0.7538 - val_loss: 0.7111 - val_acc: 0.6581
# Epoch 48/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.5588 - acc: 0.7477
# Epoch 00048: val_loss did not improve from 0.59646
# 3014/3014 [==============================] - 6s 2ms/sample - loss: 0.5583 - acc: 0.7478 - val_loss: 0.6595 - val_acc: 0.6721
# Epoch 49/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.5005 - acc: 0.7860
# Epoch 00049: val_loss improved from 0.59646 to 0.58639, saving model to /Users/sergio.dorado/Documents/GitHub_Repositories/01_Maintained/NeuralODE/models/ChlorineConcentration/ChlorineConcentration-laguerre.hdf5
# 3014/3014 [==============================] - 6s 2ms/sample - loss: 0.4999 - acc: 0.7863 - val_loss: 0.5864 - val_acc: 0.7395
# Epoch 50/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.5276 - acc: 0.7650
# Epoch 00050: val_loss improved from 0.58639 to 0.43785, saving model to /Users/sergio.dorado/Documents/GitHub_Repositories/01_Maintained/NeuralODE/models/ChlorineConcentration/ChlorineConcentration-laguerre.hdf5
# 3014/3014 [==============================] - 6s 2ms/sample - loss: 0.5267 - acc: 0.7651 - val_loss: 0.4378 - val_acc: 0.8349
# Epoch 51/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.5087 - acc: 0.7760
# Epoch 00051: val_loss did not improve from 0.43785
# 3014/3014 [==============================] - 6s 2ms/sample - loss: 0.5085 - acc: 0.7760 - val_loss: 0.4682 - val_acc: 0.8233
# Epoch 52/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.3952 - acc: 0.8283
# Epoch 00052: val_loss improved from 0.43785 to 0.41031, saving model to /Users/sergio.dorado/Documents/GitHub_Repositories/01_Maintained/NeuralODE/models/ChlorineConcentration/ChlorineConcentration-laguerre.hdf5
# 3014/3014 [==============================] - 6s 2ms/sample - loss: 0.3950 - acc: 0.8281 - val_loss: 0.4103 - val_acc: 0.8163
# Epoch 53/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.3472 - acc: 0.8530
# Epoch 00053: val_loss did not improve from 0.41031
# 3014/3014 [==============================] - 6s 2ms/sample - loss: 0.3465 - acc: 0.8530 - val_loss: 0.4410 - val_acc: 0.8000
# Epoch 54/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.3481 - acc: 0.8570
# Epoch 00054: val_loss did not improve from 0.41031
# 3014/3014 [==============================] - 6s 2ms/sample - loss: 0.3473 - acc: 0.8573 - val_loss: 0.4301 - val_acc: 0.8116
# Epoch 55/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.4011 - acc: 0.8317
# Epoch 00055: val_loss did not improve from 0.41031
# 3014/3014 [==============================] - 6s 2ms/sample - loss: 0.4026 - acc: 0.8311 - val_loss: 0.5831 - val_acc: 0.7488
# Epoch 56/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.4589 - acc: 0.7937
# Epoch 00056: val_loss did not improve from 0.41031
# 3014/3014 [==============================] - 6s 2ms/sample - loss: 0.4585 - acc: 0.7940 - val_loss: 0.4617 - val_acc: 0.8140
# Epoch 57/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.2937 - acc: 0.8810
# Epoch 00057: val_loss improved from 0.41031 to 0.33166, saving model to /Users/sergio.dorado/Documents/GitHub_Repositories/01_Maintained/NeuralODE/models/ChlorineConcentration/ChlorineConcentration-laguerre.hdf5
# 3014/3014 [==============================] - 6s 2ms/sample - loss: 0.2935 - acc: 0.8806 - val_loss: 0.3317 - val_acc: 0.8651
# Epoch 58/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.3277 - acc: 0.8620
# Epoch 00058: val_loss did not improve from 0.33166
# 3014/3014 [==============================] - 6s 2ms/sample - loss: 0.3305 - acc: 0.8603 - val_loss: 0.4032 - val_acc: 0.8163
# Epoch 59/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.3490 - acc: 0.8520
# Epoch 00059: val_loss improved from 0.33166 to 0.27286, saving model to /Users/sergio.dorado/Documents/GitHub_Repositories/01_Maintained/NeuralODE/models/ChlorineConcentration/ChlorineConcentration-laguerre.hdf5
# 3014/3014 [==============================] - 6s 2ms/sample - loss: 0.3491 - acc: 0.8517 - val_loss: 0.2729 - val_acc: 0.8930
# Epoch 60/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.2489 - acc: 0.9037
# Epoch 00060: val_loss did not improve from 0.27286
# 3014/3014 [==============================] - 6s 2ms/sample - loss: 0.2495 - acc: 0.9038 - val_loss: 0.3547 - val_acc: 0.8256
# Epoch 61/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.2744 - acc: 0.8970
# Epoch 00061: val_loss did not improve from 0.27286
# 3014/3014 [==============================] - 6s 2ms/sample - loss: 0.2738 - acc: 0.8975 - val_loss: 0.2827 - val_acc: 0.8744
# Epoch 62/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.1532 - acc: 0.9503
# Epoch 00062: val_loss did not improve from 0.27286
# 3014/3014 [==============================] - 6s 2ms/sample - loss: 0.1540 - acc: 0.9502 - val_loss: 0.4526 - val_acc: 0.8674
# Epoch 63/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.3793 - acc: 0.8417
# Epoch 00063: val_loss did not improve from 0.27286
# 3014/3014 [==============================] - 6s 2ms/sample - loss: 0.3808 - acc: 0.8404 - val_loss: 0.4419 - val_acc: 0.8256
# Epoch 64/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.3797 - acc: 0.8373
# Epoch 00064: val_loss did not improve from 0.27286
# 3014/3014 [==============================] - 6s 2ms/sample - loss: 0.3788 - acc: 0.8378 - val_loss: 0.3415 - val_acc: 0.8605
# Epoch 65/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.2114 - acc: 0.9203
# Epoch 00065: val_loss did not improve from 0.27286
# 3014/3014 [==============================] - 6s 2ms/sample - loss: 0.2110 - acc: 0.9204 - val_loss: 0.3149 - val_acc: 0.8698
# Epoch 66/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.1895 - acc: 0.9323
# Epoch 00066: val_loss improved from 0.27286 to 0.20486, saving model to /Users/sergio.dorado/Documents/GitHub_Repositories/01_Maintained/NeuralODE/models/ChlorineConcentration/ChlorineConcentration-laguerre.hdf5
# 3014/3014 [==============================] - 6s 2ms/sample - loss: 0.1887 - acc: 0.9326 - val_loss: 0.2049 - val_acc: 0.9163
# Epoch 67/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.2149 - acc: 0.9223
# Epoch 00067: val_loss did not improve from 0.20486
# 3014/3014 [==============================] - 6s 2ms/sample - loss: 0.2147 - acc: 0.9224 - val_loss: 0.3646 - val_acc: 0.8581
# Epoch 68/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.2189 - acc: 0.9190
# Epoch 00068: val_loss did not improve from 0.20486
# 3014/3014 [==============================] - 6s 2ms/sample - loss: 0.2184 - acc: 0.9194 - val_loss: 0.2106 - val_acc: 0.9116
# Epoch 69/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.1612 - acc: 0.9420
# Epoch 00069: val_loss improved from 0.20486 to 0.19520, saving model to /Users/sergio.dorado/Documents/GitHub_Repositories/01_Maintained/NeuralODE/models/ChlorineConcentration/ChlorineConcentration-laguerre.hdf5
# 3014/3014 [==============================] - 6s 2ms/sample - loss: 0.1612 - acc: 0.9419 - val_loss: 0.1952 - val_acc: 0.9256
# Epoch 70/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.1755 - acc: 0.9293
# Epoch 00070: val_loss improved from 0.19520 to 0.17719, saving model to /Users/sergio.dorado/Documents/GitHub_Repositories/01_Maintained/NeuralODE/models/ChlorineConcentration/ChlorineConcentration-laguerre.hdf5
# 3014/3014 [==============================] - 6s 2ms/sample - loss: 0.1757 - acc: 0.9290 - val_loss: 0.1772 - val_acc: 0.9209
# Epoch 71/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.1691 - acc: 0.9397
# Epoch 00071: val_loss did not improve from 0.17719
# 3014/3014 [==============================] - 6s 2ms/sample - loss: 0.1692 - acc: 0.9399 - val_loss: 0.2041 - val_acc: 0.9209
# Epoch 72/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.1906 - acc: 0.9253
# Epoch 00072: val_loss improved from 0.17719 to 0.13971, saving model to /Users/sergio.dorado/Documents/GitHub_Repositories/01_Maintained/NeuralODE/models/ChlorineConcentration/ChlorineConcentration-laguerre.hdf5
# 3014/3014 [==============================] - 6s 2ms/sample - loss: 0.1911 - acc: 0.9250 - val_loss: 0.1397 - val_acc: 0.9419
# Epoch 73/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.1100 - acc: 0.9573
# Epoch 00073: val_loss improved from 0.13971 to 0.12771, saving model to /Users/sergio.dorado/Documents/GitHub_Repositories/01_Maintained/NeuralODE/models/ChlorineConcentration/ChlorineConcentration-laguerre.hdf5
# 3014/3014 [==============================] - 6s 2ms/sample - loss: 0.1097 - acc: 0.9575 - val_loss: 0.1277 - val_acc: 0.9465
# Epoch 74/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.1137 - acc: 0.9543
# Epoch 00074: val_loss did not improve from 0.12771
# 3014/3014 [==============================] - 6s 2ms/sample - loss: 0.1145 - acc: 0.9539 - val_loss: 0.1808 - val_acc: 0.9302
# Epoch 75/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.2502 - acc: 0.9033
# Epoch 00075: val_loss did not improve from 0.12771
# 3014/3014 [==============================] - 6s 2ms/sample - loss: 0.2492 - acc: 0.9038 - val_loss: 0.2200 - val_acc: 0.9116
# Epoch 76/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.2139 - acc: 0.9213
# Epoch 00076: val_loss did not improve from 0.12771
# 3014/3014 [==============================] - 6s 2ms/sample - loss: 0.2147 - acc: 0.9210 - val_loss: 0.2491 - val_acc: 0.9070
# Epoch 77/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.2183 - acc: 0.9217
# Epoch 00077: val_loss did not improve from 0.12771
# 3014/3014 [==============================] - 6s 2ms/sample - loss: 0.2175 - acc: 0.9220 - val_loss: 0.1559 - val_acc: 0.9302
# Epoch 78/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.0892 - acc: 0.9720
# Epoch 00078: val_loss did not improve from 0.12771
# 3014/3014 [==============================] - 6s 2ms/sample - loss: 0.0892 - acc: 0.9718 - val_loss: 0.1289 - val_acc: 0.9581
# Epoch 79/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.0996 - acc: 0.9683
# Epoch 00079: val_loss improved from 0.12771 to 0.10590, saving model to /Users/sergio.dorado/Documents/GitHub_Repositories/01_Maintained/NeuralODE/models/ChlorineConcentration/ChlorineConcentration-laguerre.hdf5
# 3014/3014 [==============================] - 6s 2ms/sample - loss: 0.0992 - acc: 0.9685 - val_loss: 0.1059 - val_acc: 0.9628
# Epoch 80/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.1115 - acc: 0.9580
# Epoch 00080: val_loss did not improve from 0.10590
# 3014/3014 [==============================] - 6s 2ms/sample - loss: 0.1117 - acc: 0.9579 - val_loss: 0.4241 - val_acc: 0.8814
# Epoch 81/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.2528 - acc: 0.9067
# Epoch 00081: val_loss did not improve from 0.10590
# 3014/3014 [==============================] - 6s 2ms/sample - loss: 0.2523 - acc: 0.9068 - val_loss: 0.1924 - val_acc: 0.9163
# Epoch 82/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.1768 - acc: 0.9360
# Epoch 00082: val_loss improved from 0.10590 to 0.10456, saving model to /Users/sergio.dorado/Documents/GitHub_Repositories/01_Maintained/NeuralODE/models/ChlorineConcentration/ChlorineConcentration-laguerre.hdf5
# 3014/3014 [==============================] - 6s 2ms/sample - loss: 0.1762 - acc: 0.9363 - val_loss: 0.1046 - val_acc: 0.9721
# Epoch 83/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.0888 - acc: 0.9723
# Epoch 00083: val_loss did not improve from 0.10456
# 3014/3014 [==============================] - 6s 2ms/sample - loss: 0.0899 - acc: 0.9721 - val_loss: 0.1603 - val_acc: 0.9372
# Epoch 84/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.2458 - acc: 0.9097
# Epoch 00084: val_loss did not improve from 0.10456
# 3014/3014 [==============================] - 6s 2ms/sample - loss: 0.2452 - acc: 0.9098 - val_loss: 0.3002 - val_acc: 0.8814
# Epoch 85/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.1490 - acc: 0.9463
# Epoch 00085: val_loss did not improve from 0.10456
# 3014/3014 [==============================] - 6s 2ms/sample - loss: 0.1490 - acc: 0.9463 - val_loss: 0.1052 - val_acc: 0.9605
# Epoch 86/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.0812 - acc: 0.9747
# Epoch 00086: val_loss improved from 0.10456 to 0.04553, saving model to /Users/sergio.dorado/Documents/GitHub_Repositories/01_Maintained/NeuralODE/models/ChlorineConcentration/ChlorineConcentration-laguerre.hdf5
# 3014/3014 [==============================] - 6s 2ms/sample - loss: 0.0809 - acc: 0.9748 - val_loss: 0.0455 - val_acc: 0.9860
# Epoch 87/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.0562 - acc: 0.9833
# Epoch 00087: val_loss did not improve from 0.04553
# 3014/3014 [==============================] - 6s 2ms/sample - loss: 0.0572 - acc: 0.9824 - val_loss: 0.0837 - val_acc: 0.9674
# Epoch 88/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.3474 - acc: 0.8740
# Epoch 00088: val_loss did not improve from 0.04553
# 3014/3014 [==============================] - 6s 2ms/sample - loss: 0.3467 - acc: 0.8743 - val_loss: 0.1783 - val_acc: 0.9419
# Epoch 89/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.1044 - acc: 0.9620
# Epoch 00089: val_loss did not improve from 0.04553
# 3014/3014 [==============================] - 6s 2ms/sample - loss: 0.1041 - acc: 0.9622 - val_loss: 0.0928 - val_acc: 0.9628
# Epoch 90/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.0503 - acc: 0.9830
# Epoch 00090: val_loss did not improve from 0.04553
# 3014/3014 [==============================] - 6s 2ms/sample - loss: 0.0501 - acc: 0.9831 - val_loss: 0.0981 - val_acc: 0.9488
# Epoch 91/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.0450 - acc: 0.9867
# Epoch 00091: val_loss did not improve from 0.04553
# 3014/3014 [==============================] - 6s 2ms/sample - loss: 0.0448 - acc: 0.9867 - val_loss: 0.0482 - val_acc: 0.9860
# Epoch 92/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.0869 - acc: 0.9680
# Epoch 00092: val_loss did not improve from 0.04553
# 3014/3014 [==============================] - 6s 2ms/sample - loss: 0.0867 - acc: 0.9681 - val_loss: 0.1138 - val_acc: 0.9651
# Epoch 93/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.0896 - acc: 0.9700
# Epoch 00093: val_loss did not improve from 0.04553
# 3014/3014 [==============================] - 6s 2ms/sample - loss: 0.0893 - acc: 0.9701 - val_loss: 0.0644 - val_acc: 0.9814
# Epoch 94/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.0749 - acc: 0.9773
# Epoch 00094: val_loss did not improve from 0.04553
# 3014/3014 [==============================] - 6s 2ms/sample - loss: 0.0746 - acc: 0.9774 - val_loss: 0.0671 - val_acc: 0.9814
# Epoch 95/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.0402 - acc: 0.9873
# Epoch 00095: val_loss improved from 0.04553 to 0.03812, saving model to /Users/sergio.dorado/Documents/GitHub_Repositories/01_Maintained/NeuralODE/models/ChlorineConcentration/ChlorineConcentration-laguerre.hdf5
# 3014/3014 [==============================] - 6s 2ms/sample - loss: 0.0401 - acc: 0.9874 - val_loss: 0.0381 - val_acc: 0.9884
# Epoch 96/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.0526 - acc: 0.9843
# Epoch 00096: val_loss did not improve from 0.03812
# 3014/3014 [==============================] - 6s 2ms/sample - loss: 0.0532 - acc: 0.9841 - val_loss: 0.0707 - val_acc: 0.9698
# Epoch 97/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.0694 - acc: 0.9793
# Epoch 00097: val_loss did not improve from 0.03812
# 3014/3014 [==============================] - 6s 2ms/sample - loss: 0.0694 - acc: 0.9794 - val_loss: 0.1863 - val_acc: 0.9186
# Epoch 98/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.0850 - acc: 0.9723
# Epoch 00098: val_loss did not improve from 0.03812
# 3014/3014 [==============================] - 6s 2ms/sample - loss: 0.0847 - acc: 0.9725 - val_loss: 0.1886 - val_acc: 0.9442
# Epoch 99/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.0922 - acc: 0.9627
# Epoch 00099: val_loss did not improve from 0.03812
# 3014/3014 [==============================] - 6s 2ms/sample - loss: 0.0918 - acc: 0.9628 - val_loss: 0.1163 - val_acc: 0.9581
# Epoch 100/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.0505 - acc: 0.9847
# Epoch 00100: val_loss did not improve from 0.03812
# 3014/3014 [==============================] - 6s 2ms/sample - loss: 0.0506 - acc: 0.9847 - val_loss: 0.0919 - val_acc: 0.9628
# Epoch 101/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.1726 - acc: 0.9377
# Epoch 00101: val_loss did not improve from 0.03812
# 3014/3014 [==============================] - 6s 2ms/sample - loss: 0.1755 - acc: 0.9366 - val_loss: 0.3114 - val_acc: 0.8767
# Epoch 102/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.3003 - acc: 0.8893
# Epoch 00102: val_loss did not improve from 0.03812
# 3014/3014 [==============================] - 6s 2ms/sample - loss: 0.2992 - acc: 0.8898 - val_loss: 0.1598 - val_acc: 0.9535
# Epoch 103/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.1183 - acc: 0.9630
# Epoch 00103: val_loss did not improve from 0.03812
# 3014/3014 [==============================] - 6s 2ms/sample - loss: 0.1181 - acc: 0.9628 - val_loss: 0.1466 - val_acc: 0.9488
# Epoch 104/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.0983 - acc: 0.9670
# Epoch 00104: val_loss did not improve from 0.03812
# 3014/3014 [==============================] - 6s 2ms/sample - loss: 0.0982 - acc: 0.9672 - val_loss: 0.0545 - val_acc: 0.9860
# Epoch 105/200
# 3000/3014 [============================>.] - ETA: 0s - loss: 0.2296 - acc: 0.9187
# Epoch 00105: val_loss did not improve from 0.03812
# 3014/3014 [==============================] - 6s 2ms/sample - loss: 0.2286 - acc: 0.9190 - val_loss: 0.3798 - val_acc: 0.8581
# Training time: 565.1223361492157 s

# %%
saved_epoch = np.argmin(result.history['val_loss'])

print(f"Epoch {saved_epoch}: {result.history['val_acc'][saved_epoch]} val_acc")

model.load_weights(file_path)
model.evaluate(x_test, to_categorical(y_test))
# Out:
# Epoch 94: 0.9883720874786377 val_acc
# 863/863 [==============================] - 1s 621us/sample - loss: 0.0321 - acc: 0.9907
# [0.03214570412440344, 0.99073]
