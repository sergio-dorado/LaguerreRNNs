# %%
from architectures_v1 import *
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, RNN
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split, KFold, StratifiedKFold
from sklearn.metrics import f1_score, precision_score, recall_score, roc_auc_score, roc_curve

import os
import numpy as np
import tensorflow as tf
import pandas as pd
import time
import random

# %% [markdown]
# ## Loading Training/Testing/Validation Data

# %%
dataset = "Wafer"
model_name = "nBRC"

x_train_load = np.load(os.path.abspath(os.path.join('99_data', dataset,'x_train.npz')))
x_test_load = np.load(os.path.abspath(os.path.join('99_data', dataset,'x_test.npz')))

x_train = np.reshape(x_train_load['arr_0'], [x_train_load['arr_0'].shape[0], x_train_load['arr_0'].shape[1], 1])
x_test = np.reshape(x_test_load['arr_0'], [x_test_load['arr_0'].shape[0], x_test_load['arr_0'].shape[1], 1])

x_all = np.concatenate((x_train, x_test), axis = 0)

n_instances = x_all.shape[0]

y_train_load = np.load(os.path.abspath(os.path.join('99_data', dataset,'y_train.npz')))
y_test_load = np.load(os.path.abspath(os.path.join('99_data', dataset,'y_test.npz')))

y_train = y_train_load['arr_0']
y_test = y_test_load['arr_0']

y_all = np.concatenate((y_train, y_test), axis = 0)
y_all = np.asarray(y_all, dtype = np.uint64)

n_validation = int(0.1*n_instances)
print(f"Validation Instances: {n_validation}")

ind_validation = random.sample(range(0, n_instances), n_validation)
x_valid = x_all[ind_validation, :, :]
y_valid = y_all[ind_validation]

x_all = np.delete(x_all, ind_validation, axis = 0)
y_all = np.delete(y_all, ind_validation, axis = 0)

print(f"x_all: {x_all.shape} - y_all: {y_all.shape}")
print(f"x_valid: {x_valid.shape} - y_valid: {y_valid.shape}")
# Out:
# Validation Instances: 716
# x_all: (6448, 152, 1) - y_all: (6448,)
# x_valid: (716, 152, 1) - y_valid: (716,)

# %%
seed = 42
tf.random.set_random_seed(seed)
np.random.seed(seed)

length = x_all.shape[1]
n_features = x_all.shape[-1]

model = Sequential()

model.add(RNN(NeuromodulatedBistableRecurrentCellLayer(output_dim = 212),
              input_shape = (length, n_features), 
              return_sequences = False))
model.add(Dense(to_categorical(y_all).shape[-1], activation = "softmax"))

model.compile(optimizer = "adam", loss = "categorical_crossentropy", metrics = ["accuracy"])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rnn_1 (RNN)                  (None, 212)               90948
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 426
# =================================================================
# Total params: 91,374
# Trainable params: 91,374
# Non-trainable params: 0
# _________________________________________________________________

# %%
if not os.path.exists(os.path.abspath(os.path.join('models', dataset))):
    os.mkdir(os.path.abspath(os.path.join('models', dataset)))

kf = KFold(n_splits = 5)
sdk = StratifiedKFold(n_splits = 5, random_state = 42, shuffle = True)
df_tpr = pd.DataFrame(columns = [1, 2, 3, 4, 5])
df_fpr = pd.DataFrame(columns = [1, 2, 3, 4, 5])

n_fold = 1

acc_per_fold = []
epoch_per_fold = []
loss_per_fold = []
rec_per_fold = []
prec_per_fold = []
f1_per_fold = []
auroc_per_fold = []
fpr_per_fold = []
tpr_per_fold = []

for train, test in sdk.split(x_all, y_all):
    
    file_path = os.path.abspath(os.path.join('models', dataset, f'{dataset}-{model_name}_{n_fold}.hdf5'))

    callbacks = [
        ModelCheckpoint(filepath=file_path, monitor='val_loss', save_best_only = True, mode = 'min', verbose = 1), 
        EarlyStopping(monitor = 'val_loss', patience = 10, mode = 'min')]

    t = time.time()
    
    print(f"\nFold: {n_fold}\n")
    result = model.fit(x_all[train], 
                       to_categorical(y_all[train]),
                       epochs = 200, 
                       batch_size = 100, 
                       validation_data = (x_valid, to_categorical(y_valid)), 
                       callbacks = callbacks)

    print(f"Training time: {time.time() - t} s")

    df_results = pd.DataFrame(result.history)
    df_results.to_csv(os.path.abspath(os.path.join('models', dataset, f'{model_name}_results_{n_fold}.csv')))
    
    model.load_weights(file_path)
    scores = model.evaluate(x_all[test], to_categorical(y_all[test]))
    loss_per_fold.append(scores[0])
    acc_per_fold.append(scores[1])
    epoch_per_fold.append(np.argmin(result.history['val_loss']))
    
    # Computing predictions
    y_pred_test = np.argmax(model.predict(x_all[test]), axis = 1)
    
    # Getting performance scores per fold
    f1_per_fold.append(f1_score(y_all[test], y_pred_test, average = 'macro'))
    rec_per_fold.append(recall_score(y_all[test], y_pred_test, average = 'macro'))
    prec_per_fold.append(precision_score(y_all[test], y_pred_test, average = 'macro'))
    auroc_per_fold.append(roc_auc_score(y_all[test], y_pred_test, average = 'macro'))
    
    # Getting ROC curve for this binary classification task
    
    fpr, tpr, _ = roc_curve(y_all[test], y_pred_test)
    
    df_fpr[n_fold] = fpr
    df_tpr[n_fold] = tpr
        
    n_fold += 1

df_scores = pd.DataFrame(columns = ['F1', 'Loss', 'Accuracy', 'Precision', 'Recall', 'AUROC'])
df_scores['F1'] = f1_per_fold
df_scores['Loss'] = loss_per_fold
df_scores['Accuracy'] = acc_per_fold
df_scores['Precision'] = prec_per_fold
df_scores['Recall'] = rec_per_fold
df_scores['AUROC'] = auroc_per_fold

df_scores.to_csv(os.path.abspath(os.path.join('models', dataset, f'{model_name}_results_k-Folds.csv')))
df_tpr.to_csv(os.path.abspath(os.path.join('models', dataset, f'{model_name}_results_k-Folds_tpr.csv')))
df_fpr.to_csv(os.path.abspath(os.path.join('models', dataset, f'{model_name}_results_k-Folds_fpr.csv')))
# Out:
# Fold: 1
#
# Train on 5158 samples, validate on 716 samples
# Epoch 1/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.3812 - acc: 0.8692
# Epoch 00001: val_loss improved from inf to 0.35692, saving model to C:\Users\Sergio\Documents\GitHub_Repositories\01_Maintained\NeuralODE\models\Wafer\Wafer-nBRC_1.hdf5
# 5158/5158 [==============================] - 6s 1ms/sample - loss: 0.3815 - acc: 0.8689 - val_loss: 0.3569 - val_acc: 0.8994
# Epoch 2/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.3254 - acc: 0.8927
# Epoch 00002: val_loss improved from 0.35692 to 0.28295, saving model to C:\Users\Sergio\Documents\GitHub_Repositories\01_Maintained\NeuralODE\models\Wafer\Wafer-nBRC_1.hdf5
# 5158/5158 [==============================] - 6s 1ms/sample - loss: 0.3249 - acc: 0.8930 - val_loss: 0.2830 - val_acc: 0.8994
# Epoch 3/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.3434 - acc: 0.8922
# Epoch 00003: val_loss did not improve from 0.28295
# 5158/5158 [==============================] - 6s 1ms/sample - loss: 0.3431 - acc: 0.8920 - val_loss: 0.2936 - val_acc: 0.8994
# Epoch 4/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.2846 - acc: 0.8959
# Epoch 00004: val_loss improved from 0.28295 to 0.25752, saving model to C:\Users\Sergio\Documents\GitHub_Repositories\01_Maintained\NeuralODE\models\Wafer\Wafer-nBRC_1.hdf5
# 5158/5158 [==============================] - 6s 1ms/sample - loss: 0.2837 - acc: 0.8963 - val_loss: 0.2575 - val_acc: 0.9036
# Epoch 5/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.2329 - acc: 0.9012
# Epoch 00005: val_loss improved from 0.25752 to 0.21653, saving model to C:\Users\Sergio\Documents\GitHub_Repositories\01_Maintained\NeuralODE\models\Wafer\Wafer-nBRC_1.hdf5
# 5158/5158 [==============================] - 6s 1ms/sample - loss: 0.2330 - acc: 0.9013 - val_loss: 0.2165 - val_acc: 0.9092
# Epoch 6/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.2165 - acc: 0.9063
# Epoch 00006: val_loss improved from 0.21653 to 0.19061, saving model to C:\Users\Sergio\Documents\GitHub_Repositories\01_Maintained\NeuralODE\models\Wafer\Wafer-nBRC_1.hdf5
# 5158/5158 [==============================] - 6s 1ms/sample - loss: 0.2166 - acc: 0.9062 - val_loss: 0.1906 - val_acc: 0.9148
# Epoch 7/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.1997 - acc: 0.9255
# Epoch 00007: val_loss did not improve from 0.19061
# 5158/5158 [==============================] - 5s 1ms/sample - loss: 0.2001 - acc: 0.9254 - val_loss: 0.1951 - val_acc: 0.9413
# Epoch 8/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.1861 - acc: 0.9322
# Epoch 00008: val_loss did not improve from 0.19061
# 5158/5158 [==============================] - 5s 1ms/sample - loss: 0.1866 - acc: 0.9318 - val_loss: 0.2685 - val_acc: 0.8911
# Epoch 9/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.3282 - acc: 0.8773
# Epoch 00009: val_loss did not improve from 0.19061
# 5158/5158 [==============================] - 5s 1ms/sample - loss: 0.3272 - acc: 0.8779 - val_loss: 0.2928 - val_acc: 0.9008
# Epoch 10/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.2856 - acc: 0.8943
# Epoch 00010: val_loss did not improve from 0.19061
# 5158/5158 [==============================] - 5s 1ms/sample - loss: 0.2861 - acc: 0.8938 - val_loss: 0.2520 - val_acc: 0.8994
# Epoch 11/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.3139 - acc: 0.8957
# Epoch 00011: val_loss did not improve from 0.19061
# 5158/5158 [==============================] - 5s 1ms/sample - loss: 0.3150 - acc: 0.8949 - val_loss: 0.2918 - val_acc: 0.8994
# Epoch 12/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.2773 - acc: 0.8937
# Epoch 00012: val_loss did not improve from 0.19061
# 5158/5158 [==============================] - 6s 1ms/sample - loss: 0.2776 - acc: 0.8932 - val_loss: 0.2478 - val_acc: 0.8994
# Epoch 13/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.2338 - acc: 0.8951
# Epoch 00013: val_loss did not improve from 0.19061
# 5158/5158 [==============================] - 5s 1ms/sample - loss: 0.2337 - acc: 0.8951 - val_loss: 0.2132 - val_acc: 0.9092
# Epoch 14/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.1849 - acc: 0.9073
# Epoch 00014: val_loss improved from 0.19061 to 0.15727, saving model to C:\Users\Sergio\Documents\GitHub_Repositories\01_Maintained\NeuralODE\models\Wafer\Wafer-nBRC_1.hdf5
# 5158/5158 [==============================] - 6s 1ms/sample - loss: 0.1842 - acc: 0.9077 - val_loss: 0.1573 - val_acc: 0.9316
# Epoch 15/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.1408 - acc: 0.9449
# Epoch 00015: val_loss improved from 0.15727 to 0.13531, saving model to C:\Users\Sergio\Documents\GitHub_Repositories\01_Maintained\NeuralODE\models\Wafer\Wafer-nBRC_1.hdf5
# 5158/5158 [==============================] - 5s 1ms/sample - loss: 0.1411 - acc: 0.9451 - val_loss: 0.1353 - val_acc: 0.9651
# Epoch 16/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.1609 - acc: 0.9390
# Epoch 00016: val_loss did not improve from 0.13531
# 5158/5158 [==============================] - 5s 964us/sample - loss: 0.1608 - acc: 0.9391 - val_loss: 0.1475 - val_acc: 0.9344
# Epoch 17/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.1273 - acc: 0.9539
# Epoch 00017: val_loss improved from 0.13531 to 0.11024, saving model to C:\Users\Sergio\Documents\GitHub_Repositories\01_Maintained\NeuralODE\models\Wafer\Wafer-nBRC_1.hdf5
# 5158/5158 [==============================] - 5s 1ms/sample - loss: 0.1269 - acc: 0.9542 - val_loss: 0.1102 - val_acc: 0.9665
# Epoch 18/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.1062 - acc: 0.9661
# Epoch 00018: val_loss improved from 0.11024 to 0.09887, saving model to C:\Users\Sergio\Documents\GitHub_Repositories\01_Maintained\NeuralODE\models\Wafer\Wafer-nBRC_1.hdf5
# 5158/5158 [==============================] - 5s 1ms/sample - loss: 0.1063 - acc: 0.9659 - val_loss: 0.0989 - val_acc: 0.9749
# Epoch 19/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.0936 - acc: 0.9767
# Epoch 00019: val_loss improved from 0.09887 to 0.09447, saving model to C:\Users\Sergio\Documents\GitHub_Repositories\01_Maintained\NeuralODE\models\Wafer\Wafer-nBRC_1.hdf5
# 5158/5158 [==============================] - 5s 1ms/sample - loss: 0.0933 - acc: 0.9767 - val_loss: 0.0945 - val_acc: 0.9804
# Epoch 20/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.0793 - acc: 0.9827- ETA: 2s - l
# Epoch 00020: val_loss improved from 0.09447 to 0.07635, saving model to C:\Users\Sergio\Documents\GitHub_Repositories\01_Maintained\NeuralODE\models\Wafer\Wafer-nBRC_1.hdf5
# 5158/5158 [==============================] - 5s 1ms/sample - loss: 0.0795 - acc: 0.9827 - val_loss: 0.0763 - val_acc: 0.9860
# Epoch 21/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.0706 - acc: 0.9841
# Epoch 00021: val_loss improved from 0.07635 to 0.06852, saving model to C:\Users\Sergio\Documents\GitHub_Repositories\01_Maintained\NeuralODE\models\Wafer\Wafer-nBRC_1.hdf5
# 5158/5158 [==============================] - 5s 1ms/sample - loss: 0.0702 - acc: 0.9843 - val_loss: 0.0685 - val_acc: 0.9804
# Epoch 22/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.0684 - acc: 0.9835
# Epoch 00022: val_loss improved from 0.06852 to 0.06262, saving model to C:\Users\Sergio\Documents\GitHub_Repositories\01_Maintained\NeuralODE\models\Wafer\Wafer-nBRC_1.hdf5
# 5158/5158 [==============================] - 5s 983us/sample - loss: 0.0682 - acc: 0.9835 - val_loss: 0.0626 - val_acc: 0.9874
# Epoch 23/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.0665 - acc: 0.9851
# Epoch 00023: val_loss did not improve from 0.06262
# 5158/5158 [==============================] - 6s 1ms/sample - loss: 0.0666 - acc: 0.9849 - val_loss: 0.0690 - val_acc: 0.9832
# Epoch 24/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.0619 - acc: 0.9847
# Epoch 00024: val_loss improved from 0.06262 to 0.05729, saving model to C:\Users\Sergio\Documents\GitHub_Repositories\01_Maintained\NeuralODE\models\Wafer\Wafer-nBRC_1.hdf5
# 5158/5158 [==============================] - 6s 1ms/sample - loss: 0.0616 - acc: 0.9849 - val_loss: 0.0573 - val_acc: 0.9860
# Epoch 25/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.0556 - acc: 0.9857- ETA: 3s - loss:  - ETA: 1s - loss: 0.0558 - acc: 0.98 - ETA: 1s - loss: 0.0561
# Epoch 00025: val_loss improved from 0.05729 to 0.05098, saving model to C:\Users\Sergio\Documents\GitHub_Repositories\01_Maintained\NeuralODE\models\Wafer\Wafer-nBRC_1.hdf5
# 5158/5158 [==============================] - 6s 1ms/sample - loss: 0.0555 - acc: 0.9857 - val_loss: 0.0510 - val_acc: 0.9860
# Epoch 26/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.0506 - acc: 0.9851
# Epoch 00026: val_loss did not improve from 0.05098
# 5158/5158 [==============================] - 5s 942us/sample - loss: 0.0507 - acc: 0.9851 - val_loss: 0.0533 - val_acc: 0.9791
# Epoch 27/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.0525 - acc: 0.9855
# Epoch 00027: val_loss did not improve from 0.05098
# 5158/5158 [==============================] - 5s 1ms/sample - loss: 0.0524 - acc: 0.9857 - val_loss: 0.0620 - val_acc: 0.9818
# Epoch 28/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.0531 - acc: 0.9853
# Epoch 00028: val_loss did not improve from 0.05098
# 5158/5158 [==============================] - 5s 1ms/sample - loss: 0.0533 - acc: 0.9853 - val_loss: 0.0740 - val_acc: 0.9763
# Epoch 29/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.0653 - acc: 0.9806
# Epoch 00029: val_loss did not improve from 0.05098
# 5158/5158 [==============================] - 5s 991us/sample - loss: 0.0651 - acc: 0.9808 - val_loss: 0.0577 - val_acc: 0.9846
# Epoch 30/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.0518 - acc: 0.9847
# Epoch 00030: val_loss improved from 0.05098 to 0.04762, saving model to C:\Users\Sergio\Documents\GitHub_Repositories\01_Maintained\NeuralODE\models\Wafer\Wafer-nBRC_1.hdf5
# 5158/5158 [==============================] - 5s 1ms/sample - loss: 0.0515 - acc: 0.9849 - val_loss: 0.0476 - val_acc: 0.9860
# Epoch 31/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.2074 - acc: 0.9180
# Epoch 00031: val_loss did not improve from 0.04762
# 5158/5158 [==============================] - 5s 992us/sample - loss: 0.2070 - acc: 0.9186 - val_loss: 0.1757 - val_acc: 0.9204
# Epoch 32/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.1880 - acc: 0.9218
# Epoch 00032: val_loss did not improve from 0.04762
# 5158/5158 [==============================] - 5s 963us/sample - loss: 0.1869 - acc: 0.9225 - val_loss: 0.1362 - val_acc: 0.9595
# Epoch 33/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.1287 - acc: 0.9518
# Epoch 00033: val_loss did not improve from 0.04762
# 5158/5158 [==============================] - 5s 1ms/sample - loss: 0.1290 - acc: 0.9513 - val_loss: 0.1061 - val_acc: 0.9637
# Epoch 34/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.1240 - acc: 0.9547
# Epoch 00034: val_loss did not improve from 0.04762
# 5158/5158 [==============================] - 5s 995us/sample - loss: 0.1277 - acc: 0.9527 - val_loss: 0.1783 - val_acc: 0.9399
# Epoch 35/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.1307 - acc: 0.9514
# Epoch 00035: val_loss did not improve from 0.04762
# 5158/5158 [==============================] - 5s 997us/sample - loss: 0.1302 - acc: 0.9513 - val_loss: 0.0874 - val_acc: 0.9721
# Epoch 36/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.0861 - acc: 0.9745- ETA: 3s - loss: 0.0987 - acc - ETA: 2s - lo
# Epoch 00036: val_loss did not improve from 0.04762
# 5158/5158 [==============================] - 5s 974us/sample - loss: 0.0867 - acc: 0.9740 - val_loss: 0.0722 - val_acc: 0.9832
# Epoch 37/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.0875 - acc: 0.9733
# Epoch 00037: val_loss did not improve from 0.04762
# 5158/5158 [==============================] - 5s 1ms/sample - loss: 0.0874 - acc: 0.9732 - val_loss: 0.0954 - val_acc: 0.9609
# Epoch 38/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.0728 - acc: 0.9792
# Epoch 00038: val_loss did not improve from 0.04762
# 5158/5158 [==============================] - 5s 971us/sample - loss: 0.0725 - acc: 0.9793 - val_loss: 0.0611 - val_acc: 0.9832
# Epoch 39/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.0606 - acc: 0.9825- ETA: 1s - loss: 0.0592 -
# Epoch 00039: val_loss did not improve from 0.04762
# 5158/5158 [==============================] - 5s 964us/sample - loss: 0.0607 - acc: 0.9824 - val_loss: 0.0632 - val_acc: 0.9846
# Epoch 40/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.0602 - acc: 0.9822- ETA: 2s - loss
# Epoch 00040: val_loss did not improve from 0.04762
# 5158/5158 [==============================] - 5s 941us/sample - loss: 0.0599 - acc: 0.9824 - val_loss: 0.0521 - val_acc: 0.9818
# Training time: 213.49474120140076 s
# 1290/1290 [==============================] - 1s 749us/sample - loss: 0.0412 - acc: 0.9899
#
# Fold: 2
#
# Train on 5158 samples, validate on 716 samples
# Epoch 1/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.0499 - acc: 0.9857
# Epoch 00001: val_loss improved from inf to 0.04615, saving model to C:\Users\Sergio\Documents\GitHub_Repositories\01_Maintained\NeuralODE\models\Wafer\Wafer-nBRC_2.hdf5
# 5158/5158 [==============================] - 5s 1ms/sample - loss: 0.0497 - acc: 0.9857 - val_loss: 0.0461 - val_acc: 0.9888
# Epoch 2/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.0486 - acc: 0.9849
# Epoch 00002: val_loss improved from 0.04615 to 0.04213, saving model to C:\Users\Sergio\Documents\GitHub_Repositories\01_Maintained\NeuralODE\models\Wafer\Wafer-nBRC_2.hdf5
# 5158/5158 [==============================] - 5s 1ms/sample - loss: 0.0485 - acc: 0.9851 - val_loss: 0.0421 - val_acc: 0.9902
# Epoch 3/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.0467 - acc: 0.9865
# Epoch 00003: val_loss did not improve from 0.04213
# 5158/5158 [==============================] - 5s 1ms/sample - loss: 0.0466 - acc: 0.9864 - val_loss: 0.0471 - val_acc: 0.9902
# Epoch 4/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.0426 - acc: 0.9884
# Epoch 00004: val_loss did not improve from 0.04213
# 5158/5158 [==============================] - 5s 1ms/sample - loss: 0.0427 - acc: 0.9882 - val_loss: 0.0495 - val_acc: 0.9874
# Epoch 5/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.0415 - acc: 0.9882
# Epoch 00005: val_loss improved from 0.04213 to 0.04025, saving model to C:\Users\Sergio\Documents\GitHub_Repositories\01_Maintained\NeuralODE\models\Wafer\Wafer-nBRC_2.hdf5
# 5158/5158 [==============================] - 6s 1ms/sample - loss: 0.0412 - acc: 0.9884 - val_loss: 0.0402 - val_acc: 0.9888
# Epoch 6/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.0385 - acc: 0.9892
# Epoch 00006: val_loss did not improve from 0.04025
# 5158/5158 [==============================] - 5s 1ms/sample - loss: 0.0388 - acc: 0.9889 - val_loss: 0.0427 - val_acc: 0.9902
# Epoch 7/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.0359 - acc: 0.9892
# Epoch 00007: val_loss improved from 0.04025 to 0.03352, saving model to C:\Users\Sergio\Documents\GitHub_Repositories\01_Maintained\NeuralODE\models\Wafer\Wafer-nBRC_2.hdf5
# 5158/5158 [==============================] - 5s 973us/sample - loss: 0.0359 - acc: 0.9891 - val_loss: 0.0335 - val_acc: 0.9902
# Epoch 8/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.0357 - acc: 0.9892
# Epoch 00008: val_loss improved from 0.03352 to 0.03214, saving model to C:\Users\Sergio\Documents\GitHub_Repositories\01_Maintained\NeuralODE\models\Wafer\Wafer-nBRC_2.hdf5
# 5158/5158 [==============================] - 5s 1ms/sample - loss: 0.0361 - acc: 0.9891 - val_loss: 0.0321 - val_acc: 0.9916
# Epoch 9/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.0345 - acc: 0.9892
# Epoch 00009: val_loss did not improve from 0.03214
# 5158/5158 [==============================] - 5s 1ms/sample - loss: 0.0347 - acc: 0.9891 - val_loss: 0.0326 - val_acc: 0.9930
# Epoch 10/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.0346 - acc: 0.9884
# Epoch 00010: val_loss did not improve from 0.03214
# 5158/5158 [==============================] - 5s 949us/sample - loss: 0.0345 - acc: 0.9886 - val_loss: 0.0327 - val_acc: 0.9888
# Epoch 11/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.0334 - acc: 0.9888
# Epoch 00011: val_loss improved from 0.03214 to 0.02980, saving model to C:\Users\Sergio\Documents\GitHub_Repositories\01_Maintained\NeuralODE\models\Wafer\Wafer-nBRC_2.hdf5
# 5158/5158 [==============================] - 5s 977us/sample - loss: 0.0334 - acc: 0.9889 - val_loss: 0.0298 - val_acc: 0.9888
# Epoch 12/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.0322 - acc: 0.9908
# Epoch 00012: val_loss improved from 0.02980 to 0.02930, saving model to C:\Users\Sergio\Documents\GitHub_Repositories\01_Maintained\NeuralODE\models\Wafer\Wafer-nBRC_2.hdf5
# 5158/5158 [==============================] - 5s 1ms/sample - loss: 0.0321 - acc: 0.9909 - val_loss: 0.0293 - val_acc: 0.9902
# Epoch 13/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.0312 - acc: 0.9906
# Epoch 00013: val_loss did not improve from 0.02930
# 5158/5158 [==============================] - 5s 933us/sample - loss: 0.0310 - acc: 0.9907 - val_loss: 0.0340 - val_acc: 0.9902
# Epoch 14/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.0327 - acc: 0.9894
# Epoch 00014: val_loss improved from 0.02930 to 0.02639, saving model to C:\Users\Sergio\Documents\GitHub_Repositories\01_Maintained\NeuralODE\models\Wafer\Wafer-nBRC_2.hdf5
# 5158/5158 [==============================] - 5s 959us/sample - loss: 0.0324 - acc: 0.9895 - val_loss: 0.0264 - val_acc: 0.9916
# Epoch 15/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.0477 - acc: 0.9831
# Epoch 00015: val_loss did not improve from 0.02639
# 5158/5158 [==============================] - 5s 934us/sample - loss: 0.0480 - acc: 0.9829 - val_loss: 0.0538 - val_acc: 0.9860
# Epoch 16/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.1009 - acc: 0.9629
# Epoch 00016: val_loss did not improve from 0.02639
# 5158/5158 [==============================] - 5s 936us/sample - loss: 0.1002 - acc: 0.9634 - val_loss: 0.0719 - val_acc: 0.9721
# Epoch 17/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.1047 - acc: 0.9608
# Epoch 00017: val_loss did not improve from 0.02639
# 5158/5158 [==============================] - 5s 923us/sample - loss: 0.1041 - acc: 0.9610 - val_loss: 0.0877 - val_acc: 0.9623
# Epoch 18/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.0851 - acc: 0.9659
# Epoch 00018: val_loss did not improve from 0.02639
# 5158/5158 [==============================] - 5s 944us/sample - loss: 0.0845 - acc: 0.9663 - val_loss: 0.0652 - val_acc: 0.9804
# Epoch 19/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.0661 - acc: 0.9784
# Epoch 00019: val_loss did not improve from 0.02639
# 5158/5158 [==============================] - 5s 936us/sample - loss: 0.0662 - acc: 0.9785 - val_loss: 0.0489 - val_acc: 0.9846
# Epoch 20/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.0545 - acc: 0.9851
# Epoch 00020: val_loss did not improve from 0.02639
# 5158/5158 [==============================] - 5s 926us/sample - loss: 0.0549 - acc: 0.9851 - val_loss: 0.0478 - val_acc: 0.9888
# Epoch 21/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.0515 - acc: 0.9829
# Epoch 00021: val_loss did not improve from 0.02639
# 5158/5158 [==============================] - 5s 924us/sample - loss: 0.0513 - acc: 0.9831 - val_loss: 0.0485 - val_acc: 0.9888
# Epoch 22/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.0478 - acc: 0.9849
# Epoch 00022: val_loss did not improve from 0.02639
# 5158/5158 [==============================] - 5s 928us/sample - loss: 0.0474 - acc: 0.9851 - val_loss: 0.0402 - val_acc: 0.9888
# Epoch 23/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.1119 - acc: 0.9592
# Epoch 00023: val_loss did not improve from 0.02639
# 5158/5158 [==============================] - 5s 934us/sample - loss: 0.1120 - acc: 0.9593 - val_loss: 0.0906 - val_acc: 0.9679
# Epoch 24/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.0823 - acc: 0.9725
# Epoch 00024: val_loss did not improve from 0.02639
# 5158/5158 [==============================] - 5s 939us/sample - loss: 0.0816 - acc: 0.9729 - val_loss: 0.0616 - val_acc: 0.9818
# Training time: 120.58127188682556 s
# 1290/1290 [==============================] - 1s 732us/sample - loss: 0.0254 - acc: 0.9938
#
# Fold: 3
#
# Train on 5158 samples, validate on 716 samples
# Epoch 1/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.0294 - acc: 0.9922
# Epoch 00001: val_loss improved from inf to 0.02742, saving model to C:\Users\Sergio\Documents\GitHub_Repositories\01_Maintained\NeuralODE\models\Wafer\Wafer-nBRC_3.hdf5
# 5158/5158 [==============================] - 5s 941us/sample - loss: 0.0294 - acc: 0.9921 - val_loss: 0.0274 - val_acc: 0.9916
# Epoch 2/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.0298 - acc: 0.9912
# Epoch 00002: val_loss did not improve from 0.02742
# 5158/5158 [==============================] - 5s 939us/sample - loss: 0.0301 - acc: 0.9909 - val_loss: 0.0333 - val_acc: 0.9888
# Epoch 3/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.0267 - acc: 0.9922
# Epoch 00003: val_loss improved from 0.02742 to 0.02673, saving model to C:\Users\Sergio\Documents\GitHub_Repositories\01_Maintained\NeuralODE\models\Wafer\Wafer-nBRC_3.hdf5
# 5158/5158 [==============================] - 5s 1ms/sample - loss: 0.0272 - acc: 0.9921 - val_loss: 0.0267 - val_acc: 0.9916
# Epoch 4/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.0311 - acc: 0.9898
# Epoch 00004: val_loss did not improve from 0.02673
# 5158/5158 [==============================] - 5s 1ms/sample - loss: 0.0309 - acc: 0.9899 - val_loss: 0.0270 - val_acc: 0.9916
# Epoch 5/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.0303 - acc: 0.9892- ETA: 0s - loss: 0.0316 - acc:
# Epoch 00005: val_loss did not improve from 0.02673
# 5158/5158 [==============================] - 5s 986us/sample - loss: 0.0301 - acc: 0.9893 - val_loss: 0.0307 - val_acc: 0.9888
# Epoch 6/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.0293 - acc: 0.9910
# Epoch 00006: val_loss did not improve from 0.02673
# 5158/5158 [==============================] - 5s 961us/sample - loss: 0.0292 - acc: 0.9909 - val_loss: 0.0293 - val_acc: 0.9888
# Epoch 7/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.0295 - acc: 0.9904
# Epoch 00007: val_loss did not improve from 0.02673
# 5158/5158 [==============================] - 5s 963us/sample - loss: 0.0293 - acc: 0.9905 - val_loss: 0.0373 - val_acc: 0.9874
# Epoch 8/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.0296 - acc: 0.9898
# Epoch 00008: val_loss did not improve from 0.02673
# 5158/5158 [==============================] - 5s 985us/sample - loss: 0.0298 - acc: 0.9897 - val_loss: 0.0269 - val_acc: 0.9916
# Epoch 9/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.0299 - acc: 0.9902
# Epoch 00009: val_loss did not improve from 0.02673
# 5158/5158 [==============================] - 5s 962us/sample - loss: 0.0298 - acc: 0.9901 - val_loss: 0.0300 - val_acc: 0.9888
# Epoch 10/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.0291 - acc: 0.9898
# Epoch 00010: val_loss improved from 0.02673 to 0.02585, saving model to C:\Users\Sergio\Documents\GitHub_Repositories\01_Maintained\NeuralODE\models\Wafer\Wafer-nBRC_3.hdf5
# 5158/5158 [==============================] - 5s 987us/sample - loss: 0.0288 - acc: 0.9899 - val_loss: 0.0258 - val_acc: 0.9930
# Epoch 11/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.0288 - acc: 0.9910
# Epoch 00011: val_loss did not improve from 0.02585
# 5158/5158 [==============================] - 5s 930us/sample - loss: 0.0286 - acc: 0.9911 - val_loss: 0.0268 - val_acc: 0.9916
# Epoch 12/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.0267 - acc: 0.9910- ETA: 0s - loss: 0.0264 - acc: 0.99
# Epoch 00012: val_loss did not improve from 0.02585
# 5158/5158 [==============================] - 5s 938us/sample - loss: 0.0266 - acc: 0.9911 - val_loss: 0.0282 - val_acc: 0.9888
# Epoch 13/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.0262 - acc: 0.9925
# Epoch 00013: val_loss did not improve from 0.02585
# 5158/5158 [==============================] - 5s 947us/sample - loss: 0.0262 - acc: 0.9924 - val_loss: 0.0273 - val_acc: 0.9902
# Epoch 14/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.0274 - acc: 0.9910
# Epoch 00014: val_loss did not improve from 0.02585
# 5158/5158 [==============================] - 5s 944us/sample - loss: 0.0278 - acc: 0.9909 - val_loss: 0.0315 - val_acc: 0.9902
# Epoch 15/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.0366 - acc: 0.9873
# Epoch 00015: val_loss did not improve from 0.02585
# 5158/5158 [==============================] - 5s 1ms/sample - loss: 0.0363 - acc: 0.9874 - val_loss: 0.0303 - val_acc: 0.9916
# Epoch 16/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.0270 - acc: 0.9922
# Epoch 00016: val_loss did not improve from 0.02585
# 5158/5158 [==============================] - 5s 945us/sample - loss: 0.0272 - acc: 0.9919 - val_loss: 0.0259 - val_acc: 0.9902
# Epoch 17/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.0279 - acc: 0.9916
# Epoch 00017: val_loss improved from 0.02585 to 0.02561, saving model to C:\Users\Sergio\Documents\GitHub_Repositories\01_Maintained\NeuralODE\models\Wafer\Wafer-nBRC_3.hdf5
# 5158/5158 [==============================] - 5s 1ms/sample - loss: 0.0286 - acc: 0.9913 - val_loss: 0.0256 - val_acc: 0.9916
# Epoch 18/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.0277 - acc: 0.9902
# Epoch 00018: val_loss did not improve from 0.02561
# 5158/5158 [==============================] - 5s 1ms/sample - loss: 0.0276 - acc: 0.9903 - val_loss: 0.0328 - val_acc: 0.9888
# Epoch 19/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.0283 - acc: 0.9906
# Epoch 00019: val_loss did not improve from 0.02561
# 5158/5158 [==============================] - 5s 1ms/sample - loss: 0.0281 - acc: 0.9907 - val_loss: 0.0258 - val_acc: 0.9930
# Epoch 20/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.0262 - acc: 0.9916
# Epoch 00020: val_loss did not improve from 0.02561
# 5158/5158 [==============================] - 6s 1ms/sample - loss: 0.0260 - acc: 0.9917 - val_loss: 0.0323 - val_acc: 0.9874
# Epoch 21/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.0249 - acc: 0.9922
# Epoch 00021: val_loss did not improve from 0.02561
# 5158/5158 [==============================] - 5s 1ms/sample - loss: 0.0249 - acc: 0.9921 - val_loss: 0.0265 - val_acc: 0.9888
# Epoch 22/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.0498 - acc: 0.9806
# Epoch 00022: val_loss did not improve from 0.02561
# 5158/5158 [==============================] - 5s 1ms/sample - loss: 0.0502 - acc: 0.9804 - val_loss: 0.0539 - val_acc: 0.9818
# Epoch 23/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.0367 - acc: 0.9869
# Epoch 00023: val_loss did not improve from 0.02561
# 5158/5158 [==============================] - 6s 1ms/sample - loss: 0.0364 - acc: 0.9870 - val_loss: 0.0333 - val_acc: 0.9860
# Epoch 24/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.0282 - acc: 0.9914
# Epoch 00024: val_loss did not improve from 0.02561
# 5158/5158 [==============================] - 5s 972us/sample - loss: 0.0279 - acc: 0.9915 - val_loss: 0.0268 - val_acc: 0.9916
# Epoch 25/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.0265 - acc: 0.9908
# Epoch 00025: val_loss did not improve from 0.02561
# 5158/5158 [==============================] - 5s 942us/sample - loss: 0.0263 - acc: 0.9909 - val_loss: 0.0379 - val_acc: 0.9874
# Epoch 26/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.0307 - acc: 0.9894
# Epoch 00026: val_loss did not improve from 0.02561
# 5158/5158 [==============================] - 5s 936us/sample - loss: 0.0307 - acc: 0.9893 - val_loss: 0.0299 - val_acc: 0.9888
# Epoch 27/200
# 5100/5158 [============================>.] - ETA: 0s - loss: 0.0329 - acc: 0.9875- ETA: 2s
# Epoch 00027: val_loss did not improve from 0.02561
# 5158/5158 [==============================] - 5s 941us/sample - loss: 0.0332 - acc: 0.9872 - val_loss: 0.0328 - val_acc: 0.9888
# Training time: 136.96314191818237 s
# 1290/1290 [==============================] - 1s 746us/sample - loss: 0.0244 - acc: 0.9938
#
# Fold: 4
#
# Train on 5159 samples, validate on 716 samples
# Epoch 1/200
# 5100/5159 [============================>.] - ETA: 0s - loss: 0.0289 - acc: 0.9902
# Epoch 00001: val_loss improved from inf to 0.02627, saving model to C:\Users\Sergio\Documents\GitHub_Repositories\01_Maintained\NeuralODE\models\Wafer\Wafer-nBRC_4.hdf5
# 5159/5159 [==============================] - 5s 943us/sample - loss: 0.0288 - acc: 0.9903 - val_loss: 0.0263 - val_acc: 0.9916
# Epoch 2/200
# 5100/5159 [============================>.] - ETA: 0s - loss: 0.0269 - acc: 0.9912
# Epoch 00002: val_loss improved from 0.02627 to 0.02487, saving model to C:\Users\Sergio\Documents\GitHub_Repositories\01_Maintained\NeuralODE\models\Wafer\Wafer-nBRC_4.hdf5
# 5159/5159 [==============================] - 5s 998us/sample - loss: 0.0267 - acc: 0.9913 - val_loss: 0.0249 - val_acc: 0.9888
# Epoch 3/200
# 5100/5159 [============================>.] - ETA: 0s - loss: 0.0259 - acc: 0.9920
# Epoch 00003: val_loss did not improve from 0.02487
# 5159/5159 [==============================] - 5s 1ms/sample - loss: 0.0264 - acc: 0.9919 - val_loss: 0.0339 - val_acc: 0.9888
# Epoch 4/200
# 5100/5159 [============================>.] - ETA: 0s - loss: 0.0248 - acc: 0.9931
# Epoch 00004: val_loss improved from 0.02487 to 0.02449, saving model to C:\Users\Sergio\Documents\GitHub_Repositories\01_Maintained\NeuralODE\models\Wafer\Wafer-nBRC_4.hdf5
# 5159/5159 [==============================] - 5s 1ms/sample - loss: 0.0246 - acc: 0.9932 - val_loss: 0.0245 - val_acc: 0.9930
# Epoch 5/200
# 5100/5159 [============================>.] - ETA: 0s - loss: 0.0345 - acc: 0.9884
# Epoch 00005: val_loss did not improve from 0.02449
# 5159/5159 [==============================] - 5s 1ms/sample - loss: 0.0343 - acc: 0.9886 - val_loss: 0.0337 - val_acc: 0.9902
# Epoch 6/200
# 5100/5159 [============================>.] - ETA: 0s - loss: 0.0287 - acc: 0.9900
# Epoch 00006: val_loss did not improve from 0.02449
# 5159/5159 [==============================] - 5s 1ms/sample - loss: 0.0288 - acc: 0.9899 - val_loss: 0.0295 - val_acc: 0.9902
# Epoch 7/200
# 5100/5159 [============================>.] - ETA: 0s - loss: 0.0276 - acc: 0.9906
# Epoch 00007: val_loss did not improve from 0.02449
# 5159/5159 [==============================] - 5s 1ms/sample - loss: 0.0275 - acc: 0.9907 - val_loss: 0.0366 - val_acc: 0.9860
# Epoch 8/200
# 5100/5159 [============================>.] - ETA: 0s - loss: 0.0275 - acc: 0.9900
# Epoch 00008: val_loss did not improve from 0.02449
# 5159/5159 [==============================] - 5s 961us/sample - loss: 0.0275 - acc: 0.9899 - val_loss: 0.0441 - val_acc: 0.9818
# Epoch 9/200
# 5100/5159 [============================>.] - ETA: 0s - loss: 0.0310 - acc: 0.9884
# Epoch 00009: val_loss did not improve from 0.02449
# 5159/5159 [==============================] - 5s 1ms/sample - loss: 0.0308 - acc: 0.9886 - val_loss: 0.0359 - val_acc: 0.9846
# Epoch 10/200
# 5100/5159 [============================>.] - ETA: 0s - loss: 0.0262 - acc: 0.9908
# Epoch 00010: val_loss did not improve from 0.02449
# 5159/5159 [==============================] - 5s 1ms/sample - loss: 0.0261 - acc: 0.9907 - val_loss: 0.0294 - val_acc: 0.9902
# Epoch 11/200
# 5100/5159 [============================>.] - ETA: 0s - loss: 0.0262 - acc: 0.9914
# Epoch 00011: val_loss did not improve from 0.02449
# 5159/5159 [==============================] - 5s 1ms/sample - loss: 0.0262 - acc: 0.9913 - val_loss: 0.0337 - val_acc: 0.9874
# Epoch 12/200
# 5100/5159 [============================>.] - ETA: 0s - loss: 0.0356 - acc: 0.9863
# Epoch 00012: val_loss did not improve from 0.02449
# 5159/5159 [==============================] - 5s 1ms/sample - loss: 0.0354 - acc: 0.9864 - val_loss: 0.0408 - val_acc: 0.9888
# Epoch 13/200
# 5100/5159 [============================>.] - ETA: 0s - loss: 0.0342 - acc: 0.9892
# Epoch 00013: val_loss did not improve from 0.02449
# 5159/5159 [==============================] - 5s 998us/sample - loss: 0.0339 - acc: 0.9893 - val_loss: 0.0581 - val_acc: 0.9818
# Epoch 14/200
# 5100/5159 [============================>.] - ETA: 0s - loss: 0.0358 - acc: 0.9880
# Epoch 00014: val_loss did not improve from 0.02449
# 5159/5159 [==============================] - 5s 1ms/sample - loss: 0.0355 - acc: 0.9882 - val_loss: 0.0376 - val_acc: 0.9902
# Training time: 73.09056997299194 s
# 1289/1289 [==============================] - 1s 768us/sample - loss: 0.0307 - acc: 0.9915
#
# Fold: 5
#
# Train on 5159 samples, validate on 716 samples
# Epoch 1/200
# 5100/5159 [============================>.] - ETA: 0s - loss: 0.0265 - acc: 0.9920
# Epoch 00001: val_loss improved from inf to 0.03237, saving model to C:\Users\Sergio\Documents\GitHub_Repositories\01_Maintained\NeuralODE\models\Wafer\Wafer-nBRC_5.hdf5
# 5159/5159 [==============================] - 5s 1ms/sample - loss: 0.0264 - acc: 0.9921 - val_loss: 0.0324 - val_acc: 0.9888
# Epoch 2/200
# 5100/5159 [============================>.] - ETA: 0s - loss: 0.0323 - acc: 0.9884
# Epoch 00002: val_loss improved from 0.03237 to 0.02403, saving model to C:\Users\Sergio\Documents\GitHub_Repositories\01_Maintained\NeuralODE\models\Wafer\Wafer-nBRC_5.hdf5
# 5159/5159 [==============================] - 5s 1ms/sample - loss: 0.0320 - acc: 0.9886 - val_loss: 0.0240 - val_acc: 0.9930
# Epoch 3/200
# 5100/5159 [============================>.] - ETA: 0s - loss: 0.0252 - acc: 0.9920
# Epoch 00003: val_loss did not improve from 0.02403
# 5159/5159 [==============================] - 5s 986us/sample - loss: 0.0251 - acc: 0.9921 - val_loss: 0.0263 - val_acc: 0.9902
# Epoch 4/200
# 5100/5159 [============================>.] - ETA: 0s - loss: 0.0340 - acc: 0.9867
# Epoch 00004: val_loss did not improve from 0.02403
# 5159/5159 [==============================] - 5s 1ms/sample - loss: 0.0342 - acc: 0.9866 - val_loss: 0.0280 - val_acc: 0.9902
# Epoch 5/200
# 5100/5159 [============================>.] - ETA: 0s - loss: 0.0352 - acc: 0.9865
# Epoch 00005: val_loss did not improve from 0.02403
# 5159/5159 [==============================] - 5s 1ms/sample - loss: 0.0350 - acc: 0.9866 - val_loss: 0.0417 - val_acc: 0.9888
# Epoch 6/200
# 5100/5159 [============================>.] - ETA: 0s - loss: 0.0519 - acc: 0.9829
# Epoch 00006: val_loss did not improve from 0.02403
# 5159/5159 [==============================] - 6s 1ms/sample - loss: 0.0522 - acc: 0.9827 - val_loss: 0.1527 - val_acc: 0.9218
# Epoch 7/200
# 5100/5159 [============================>.] - ETA: 0s - loss: 0.0500 - acc: 0.9843
# Epoch 00007: val_loss did not improve from 0.02403
# 5159/5159 [==============================] - 6s 1ms/sample - loss: 0.0500 - acc: 0.9843 - val_loss: 0.0393 - val_acc: 0.9860
# Epoch 8/200
# 5100/5159 [============================>.] - ETA: 0s - loss: 0.0360 - acc: 0.9888
# Epoch 00008: val_loss did not improve from 0.02403
# 5159/5159 [==============================] - 6s 1ms/sample - loss: 0.0358 - acc: 0.9888 - val_loss: 0.0355 - val_acc: 0.9916
# Epoch 9/200
# 5100/5159 [============================>.] - ETA: 0s - loss: 0.0340 - acc: 0.9902
# Epoch 00009: val_loss did not improve from 0.02403
# 5159/5159 [==============================] - 5s 1ms/sample - loss: 0.0347 - acc: 0.9899 - val_loss: 0.0391 - val_acc: 0.9860
# Epoch 10/200
# 5100/5159 [============================>.] - ETA: 0s - loss: 0.0356 - acc: 0.9878
# Epoch 00010: val_loss did not improve from 0.02403
# 5159/5159 [==============================] - 5s 1ms/sample - loss: 0.0353 - acc: 0.9880 - val_loss: 0.0366 - val_acc: 0.9874
# Epoch 11/200
# 5100/5159 [============================>.] - ETA: 0s - loss: 0.0346 - acc: 0.9892
# Epoch 00011: val_loss did not improve from 0.02403
# 5159/5159 [==============================] - 5s 1ms/sample - loss: 0.0344 - acc: 0.9893 - val_loss: 0.0352 - val_acc: 0.9888
# Epoch 12/200
# 5100/5159 [============================>.] - ETA: 0s - loss: 0.0643 - acc: 0.9749
# Epoch 00012: val_loss did not improve from 0.02403
# 5159/5159 [==============================] - 5s 1ms/sample - loss: 0.0649 - acc: 0.9746 - val_loss: 0.0996 - val_acc: 0.9679
# Training time: 64.1864583492279 s
# 1289/1289 [==============================] - 1s 771us/sample - loss: 0.0338 - acc: 0.9907
