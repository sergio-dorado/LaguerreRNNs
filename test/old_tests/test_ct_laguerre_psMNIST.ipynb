# %%
from architectures_v1 import *
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, RNN
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

import os
import numpy as np
import tensorflow as tf
import pandas as pd
import time

# %% [markdown]
# ## Loading Training/Testing/Validation Data

# %%
dataset = "PMNIST"

x_train_load = np.load(os.path.abspath(os.path.join('99_data', dataset,'x_train.npz')))
x_test_load = np.load(os.path.abspath(os.path.join('99_data', dataset, 'x_test.npz')))
x_valid_load = np.load(os.path.abspath(os.path.join('99_data', dataset,'x_valid.npz')))

x_train = x_train_load['arr_0']
x_test = x_test_load['arr_0']
x_valid = x_valid_load['arr_0']

y_train_load = np.load(os.path.abspath(os.path.join('99_data', dataset,'y_train.npz')))
y_test_load = np.load(os.path.abspath(os.path.join('99_data', dataset,'y_test.npz')))
y_valid_load = np.load(os.path.abspath(os.path.join('99_data', dataset,'y_valid.npz')))

y_train = y_train_load['arr_0']
y_test = y_test_load['arr_0']
y_valid = y_valid_load['arr_0']

print(f"x_train: {x_train.shape} - y_train: {y_train.shape}")
print(f"x_test: {x_test.shape} - y_test: {y_test.shape}")
print(f"x_valid: {x_valid.shape} - y_valid: {y_valid.shape}")
# Out:
# x_train: (50000, 784, 1) - y_train: (50000,)
# x_test: (10000, 784, 1) - y_test: (10000,)
# x_valid: (10000, 784, 1) - y_valid: (10000,)

# %%
seed = 42
tf.random.set_random_seed(seed)
np.random.seed(seed)

length = x_train.shape[1]
n_features = x_train.shape[-1]

model = Sequential()

model.add(RNN(OrthogonalCell(units = 212,
                             order = 256,
                             variant = 'ct_legendre',
                             theta = 28**2,
                             dt = 1,
                            input_dims = 1), 
              input_shape = (length, n_features),
             return_sequences = False))
model.add(Dense(to_categorical(y_train).shape[-1], activation = "softmax"))

model.compile(optimizer = "adam", loss = "categorical_crossentropy", metrics = ["accuracy"])
model.summary()
# Out:
# WARNING:tensorflow:From /home/dorads/miniconda3/envs/sd_dev_tf_1/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rnn (RNN)                    (None, 212)               165691
# _________________________________________________________________
# dense (Dense)                (None, 10)                2130
# =================================================================
# Total params: 167,821
# Trainable params: 102,027
# Non-trainable params: 65,794
# _________________________________________________________________

# %%
if not os.path.exists(os.path.abspath(os.path.join('models', dataset))):
    os.mkdir(os.path.abspath(os.path.join('models', dataset)))

file_path = os.path.abspath(os.path.join('models', dataset, f'{dataset}-laguerre.hdf5'))

callbacks = [
    ModelCheckpoint(filepath=file_path, monitor='val_loss', save_best_only = True, mode = 'min', verbose = 1), 
    EarlyStopping(monitor = 'val_loss', patience = 10, mode = 'min')]

t = time.time()

result = model.fit(x_train, 
                   to_categorical(y_train),
                   epochs = 200, 
                   batch_size = 100, 
                   validation_data = (x_valid, to_categorical(y_valid)), 
                   callbacks = callbacks)

print(f"Training time: {time.time() - t} s")

df_results = pd.DataFrame(result.history)
df_results.to_csv(os.path.abspath(os.path.join('models', dataset, 'laguerre_results.csv')))
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/200
# 49900/50000 [============================>.] - ETA: 0s - loss: 0.3665 - acc: 0.8891
# Epoch 00001: val_loss improved from inf to 0.23525, saving model to /data/home/dorads/Documents/GitHub_Repositories/01_Maintained/NeuralODE/models/PMNIST/PMNIST-laguerre.hdf5
# 50000/50000 [==============================] - 175s 3ms/sample - loss: 0.3661 - acc: 0.8892 - val_loss: 0.2352 - val_acc: 0.9304
# Epoch 2/200
# 49900/50000 [============================>.] - ETA: 0s - loss: 0.1900 - acc: 0.9416
# Epoch 00002: val_loss improved from 0.23525 to 0.19062, saving model to /data/home/dorads/Documents/GitHub_Repositories/01_Maintained/NeuralODE/models/PMNIST/PMNIST-laguerre.hdf5
# 50000/50000 [==============================] - 173s 3ms/sample - loss: 0.1898 - acc: 0.9416 - val_loss: 0.1906 - val_acc: 0.9400
# Epoch 3/200
# 49900/50000 [============================>.] - ETA: 0s - loss: 0.1414 - acc: 0.9561
# Epoch 00003: val_loss improved from 0.19062 to 0.16172, saving model to /data/home/dorads/Documents/GitHub_Repositories/01_Maintained/NeuralODE/models/PMNIST/PMNIST-laguerre.hdf5
# 50000/50000 [==============================] - 171s 3ms/sample - loss: 0.1413 - acc: 0.9561 - val_loss: 0.1617 - val_acc: 0.9478
# Epoch 4/200
# 49900/50000 [============================>.] - ETA: 0s - loss: 0.3779 - acc: 0.8794
# Epoch 00004: val_loss did not improve from 0.16172
# 50000/50000 [==============================] - 175s 4ms/sample - loss: 0.3787 - acc: 0.8791 - val_loss: 0.6843 - val_acc: 0.7813
# Epoch 5/200
# 49900/50000 [============================>.] - ETA: 0s - loss: 0.4617 - acc: 0.8574
# Epoch 00005: val_loss did not improve from 0.16172
# 50000/50000 [==============================] - 174s 3ms/sample - loss: 0.4618 - acc: 0.8574 - val_loss: 0.3701 - val_acc: 0.8876
# Epoch 6/200
# 49900/50000 [============================>.] - ETA: 0s - loss: 0.3066 - acc: 0.9047
# Epoch 00006: val_loss did not improve from 0.16172
# 50000/50000 [==============================] - 168s 3ms/sample - loss: 0.3065 - acc: 0.9047 - val_loss: 0.2990 - val_acc: 0.9078
# Epoch 7/200
# 49900/50000 [============================>.] - ETA: 0s - loss: 0.2347 - acc: 0.9279
# Epoch 00007: val_loss did not improve from 0.16172
# 50000/50000 [==============================] - 164s 3ms/sample - loss: 0.2350 - acc: 0.9279 - val_loss: 0.2403 - val_acc: 0.9273
# Epoch 8/200
# 49900/50000 [============================>.] - ETA: 0s - loss: 0.2025 - acc: 0.9378
# Epoch 00008: val_loss did not improve from 0.16172
# 50000/50000 [==============================] - 164s 3ms/sample - loss: 0.2026 - acc: 0.9377 - val_loss: 0.2746 - val_acc: 0.9159
# Epoch 9/200
# 49900/50000 [============================>.] - ETA: 0s - loss: 0.1681 - acc: 0.9477
# Epoch 00009: val_loss did not improve from 0.16172
# 50000/50000 [==============================] - 165s 3ms/sample - loss: 0.1680 - acc: 0.9477 - val_loss: 0.1836 - val_acc: 0.9440
# Epoch 10/200
# 49900/50000 [============================>.] - ETA: 0s - loss: 0.1359 - acc: 0.9588
# Epoch 00010: val_loss did not improve from 0.16172
# 50000/50000 [==============================] - 174s 3ms/sample - loss: 0.1358 - acc: 0.9588 - val_loss: 0.1660 - val_acc: 0.9503
# Epoch 11/200
# 49900/50000 [============================>.] - ETA: 0s - loss: 0.1149 - acc: 0.9657
# Epoch 00011: val_loss improved from 0.16172 to 0.15655, saving model to /data/home/dorads/Documents/GitHub_Repositories/01_Maintained/NeuralODE/models/PMNIST/PMNIST-laguerre.hdf5
# 50000/50000 [==============================] - 173s 3ms/sample - loss: 0.1149 - acc: 0.9656 - val_loss: 0.1566 - val_acc: 0.9519
# Epoch 12/200
# 49900/50000 [============================>.] - ETA: 0s - loss: 0.0982 - acc: 0.9715
# Epoch 00012: val_loss improved from 0.15655 to 0.15038, saving model to /data/home/dorads/Documents/GitHub_Repositories/01_Maintained/NeuralODE/models/PMNIST/PMNIST-laguerre.hdf5
# 50000/50000 [==============================] - 173s 3ms/sample - loss: 0.0982 - acc: 0.9715 - val_loss: 0.1504 - val_acc: 0.9533
# Epoch 13/200
# 49900/50000 [============================>.] - ETA: 0s - loss: 0.0876 - acc: 0.9737
# Epoch 00013: val_loss improved from 0.15038 to 0.13221, saving model to /data/home/dorads/Documents/GitHub_Repositories/01_Maintained/NeuralODE/models/PMNIST/PMNIST-laguerre.hdf5
# 50000/50000 [==============================] - 172s 3ms/sample - loss: 0.0877 - acc: 0.9737 - val_loss: 0.1322 - val_acc: 0.9587
# Epoch 14/200
# 49900/50000 [============================>.] - ETA: 0s - loss: 0.0741 - acc: 0.9781
# Epoch 00014: val_loss did not improve from 0.13221
# 50000/50000 [==============================] - 173s 3ms/sample - loss: 0.0742 - acc: 0.9781 - val_loss: 0.1341 - val_acc: 0.9577
# Epoch 15/200
# 49900/50000 [============================>.] - ETA: 0s - loss: 0.0651 - acc: 0.9812
# Epoch 00015: val_loss improved from 0.13221 to 0.12573, saving model to /data/home/dorads/Documents/GitHub_Repositories/01_Maintained/NeuralODE/models/PMNIST/PMNIST-laguerre.hdf5
# 50000/50000 [==============================] - 174s 3ms/sample - loss: 0.0651 - acc: 0.9812 - val_loss: 0.1257 - val_acc: 0.9622
# Epoch 16/200
# 49900/50000 [============================>.] - ETA: 0s - loss: 0.0554 - acc: 0.9839
# Epoch 00016: val_loss did not improve from 0.12573
# 50000/50000 [==============================] - 174s 3ms/sample - loss: 0.0555 - acc: 0.9839 - val_loss: 0.1275 - val_acc: 0.9625
# Epoch 17/200
# 49900/50000 [============================>.] - ETA: 0s - loss: 0.0501 - acc: 0.9850
# Epoch 00017: val_loss did not improve from 0.12573
# 50000/50000 [==============================] - 177s 4ms/sample - loss: 0.0500 - acc: 0.9850 - val_loss: 0.1313 - val_acc: 0.9595
# Epoch 18/200
# 49900/50000 [============================>.] - ETA: 0s - loss: 0.0405 - acc: 0.9884
# Epoch 00018: val_loss did not improve from 0.12573
# 50000/50000 [==============================] - 173s 3ms/sample - loss: 0.0406 - acc: 0.9883 - val_loss: 0.1264 - val_acc: 0.9623
# Epoch 19/200
# 49900/50000 [============================>.] - ETA: 0s - loss: 0.0375 - acc: 0.9892
# Epoch 00019: val_loss did not improve from 0.12573
# 50000/50000 [==============================] - 176s 4ms/sample - loss: 0.0374 - acc: 0.9892 - val_loss: 0.1292 - val_acc: 0.9600
# Epoch 20/200
# 49900/50000 [============================>.] - ETA: 0s - loss: 0.0353 - acc: 0.9892
# Epoch 00020: val_loss did not improve from 0.12573
# 50000/50000 [==============================] - 175s 3ms/sample - loss: 0.0353 - acc: 0.9892 - val_loss: 0.1281 - val_acc: 0.9634
# Epoch 21/200
# 49900/50000 [============================>.] - ETA: 0s - loss: 0.0301 - acc: 0.9915
# Epoch 00021: val_loss did not improve from 0.12573
# 50000/50000 [==============================] - 174s 3ms/sample - loss: 0.0301 - acc: 0.9915 - val_loss: 0.1277 - val_acc: 0.9626
# Epoch 22/200
# 49900/50000 [============================>.] - ETA: 0s - loss: 0.0284 - acc: 0.9914
# Epoch 00022: val_loss did not improve from 0.12573
# 50000/50000 [==============================] - 173s 3ms/sample - loss: 0.0285 - acc: 0.9914 - val_loss: 0.1341 - val_acc: 0.9607
# Epoch 23/200
# 49900/50000 [============================>.] - ETA: 0s - loss: 0.0220 - acc: 0.9938
# Epoch 00023: val_loss did not improve from 0.12573
# 50000/50000 [==============================] - 176s 4ms/sample - loss: 0.0220 - acc: 0.9938 - val_loss: 0.1466 - val_acc: 0.9572
# Epoch 24/200
# 49900/50000 [============================>.] - ETA: 0s - loss: 0.0234 - acc: 0.9932
# Epoch 00024: val_loss improved from 0.12573 to 0.12457, saving model to /data/home/dorads/Documents/GitHub_Repositories/01_Maintained/NeuralODE/models/PMNIST/PMNIST-laguerre.hdf5
# 50000/50000 [==============================] - 175s 3ms/sample - loss: 0.0234 - acc: 0.9932 - val_loss: 0.1246 - val_acc: 0.9660
# Epoch 25/200
# 49900/50000 [============================>.] - ETA: 0s - loss: 0.0238 - acc: 0.9921
# Epoch 00025: val_loss did not improve from 0.12457
# 50000/50000 [==============================] - 173s 3ms/sample - loss: 0.0238 - acc: 0.9921 - val_loss: 0.1398 - val_acc: 0.9624
# Epoch 26/200
# 49900/50000 [============================>.] - ETA: 0s - loss: 0.0229 - acc: 0.9930
# Epoch 00026: val_loss did not improve from 0.12457
# 50000/50000 [==============================] - 172s 3ms/sample - loss: 0.0231 - acc: 0.9929 - val_loss: 0.1682 - val_acc: 0.9517
# Epoch 27/200
# 49900/50000 [============================>.] - ETA: 0s - loss: 0.0244 - acc: 0.9921
# Epoch 00027: val_loss did not improve from 0.12457
# 50000/50000 [==============================] - 174s 3ms/sample - loss: 0.0243 - acc: 0.9921 - val_loss: 0.1367 - val_acc: 0.9628
# Epoch 28/200
# 49900/50000 [============================>.] - ETA: 0s - loss: 0.0119 - acc: 0.9969
# Epoch 00028: val_loss did not improve from 0.12457
# 50000/50000 [==============================] - 172s 3ms/sample - loss: 0.0119 - acc: 0.9969 - val_loss: 0.1400 - val_acc: 0.9644
# Epoch 29/200
# 49900/50000 [============================>.] - ETA: 0s - loss: 0.0218 - acc: 0.9930
# Epoch 00029: val_loss did not improve from 0.12457
# 50000/50000 [==============================] - 174s 3ms/sample - loss: 0.0218 - acc: 0.9929 - val_loss: 0.1583 - val_acc: 0.9605
# Epoch 30/200
# 49900/50000 [============================>.] - ETA: 0s - loss: 0.0233 - acc: 0.9919
# Epoch 00030: val_loss did not improve from 0.12457
# 50000/50000 [==============================] - 175s 4ms/sample - loss: 0.0233 - acc: 0.9919 - val_loss: 0.1459 - val_acc: 0.9630
# Epoch 31/200
# 49900/50000 [============================>.] - ETA: 0s - loss: 0.0102 - acc: 0.9975
# Epoch 00031: val_loss did not improve from 0.12457
# 50000/50000 [==============================] - 177s 4ms/sample - loss: 0.0101 - acc: 0.9975 - val_loss: 0.1334 - val_acc: 0.9655
# Epoch 32/200
# 49900/50000 [============================>.] - ETA: 0s - loss: 0.0022 - acc: 0.9999
# Epoch 00032: val_loss improved from 0.12457 to 0.12329, saving model to /data/home/dorads/Documents/GitHub_Repositories/01_Maintained/NeuralODE/models/PMNIST/PMNIST-laguerre.hdf5
# 50000/50000 [==============================] - 178s 4ms/sample - loss: 0.0022 - acc: 0.9999 - val_loss: 0.1233 - val_acc: 0.9687
# Epoch 33/200
# 49900/50000 [============================>.] - ETA: 0s - loss: 0.0010 - acc: 1.0000
# Epoch 00033: val_loss improved from 0.12329 to 0.11941, saving model to /data/home/dorads/Documents/GitHub_Repositories/01_Maintained/NeuralODE/models/PMNIST/PMNIST-laguerre.hdf5
# 50000/50000 [==============================] - 178s 4ms/sample - loss: 0.0010 - acc: 1.0000 - val_loss: 0.1194 - val_acc: 0.9702
# Epoch 34/200
# 49900/50000 [============================>.] - ETA: 0s - loss: 7.1950e-04 - acc: 1.0000
# Epoch 00034: val_loss did not improve from 0.11941
# 50000/50000 [==============================] - 179s 4ms/sample - loss: 7.1994e-04 - acc: 1.0000 - val_loss: 0.1219 - val_acc: 0.9709
# Epoch 35/200
# 49900/50000 [============================>.] - ETA: 0s - loss: 5.8485e-04 - acc: 1.0000
# Epoch 00035: val_loss did not improve from 0.11941
# 50000/50000 [==============================] - 178s 4ms/sample - loss: 5.8453e-04 - acc: 1.0000 - val_loss: 0.1230 - val_acc: 0.9703
# Epoch 36/200
# 49900/50000 [============================>.] - ETA: 0s - loss: 0.0567 - acc: 0.9822
# Epoch 00036: val_loss did not improve from 0.11941
# 50000/50000 [==============================] - 177s 4ms/sample - loss: 0.0568 - acc: 0.9822 - val_loss: 0.1938 - val_acc: 0.9503
# Epoch 37/200
# 49900/50000 [============================>.] - ETA: 0s - loss: 0.0622 - acc: 0.9786
# Epoch 00037: val_loss did not improve from 0.11941
# 50000/50000 [==============================] - 176s 4ms/sample - loss: 0.0621 - acc: 0.9786 - val_loss: 0.1388 - val_acc: 0.9614
# Epoch 38/200
# 49900/50000 [============================>.] - ETA: 0s - loss: 0.0213 - acc: 0.9931
# Epoch 00038: val_loss did not improve from 0.11941
# 50000/50000 [==============================] - 174s 3ms/sample - loss: 0.0214 - acc: 0.9931 - val_loss: 0.1361 - val_acc: 0.9635
# Epoch 39/200
# 49900/50000 [============================>.] - ETA: 0s - loss: 0.0091 - acc: 0.9979
# Epoch 00039: val_loss did not improve from 0.11941
# 50000/50000 [==============================] - 173s 3ms/sample - loss: 0.0091 - acc: 0.9979 - val_loss: 0.1233 - val_acc: 0.9688
# Epoch 40/200
# 49900/50000 [============================>.] - ETA: 0s - loss: 0.0064 - acc: 0.9985
# Epoch 00040: val_loss did not improve from 0.11941
# 50000/50000 [==============================] - 175s 4ms/sample - loss: 0.0064 - acc: 0.9985 - val_loss: 0.1364 - val_acc: 0.9673
# Epoch 41/200
# 49900/50000 [============================>.] - ETA: 0s - loss: 0.0116 - acc: 0.9968
# Epoch 00041: val_loss did not improve from 0.11941
# 50000/50000 [==============================] - 178s 4ms/sample - loss: 0.0116 - acc: 0.9968 - val_loss: 0.1729 - val_acc: 0.9553
# Epoch 42/200
# 49900/50000 [============================>.] - ETA: 0s - loss: 0.0297 - acc: 0.9898
# Epoch 00042: val_loss did not improve from 0.11941
# 50000/50000 [==============================] - 178s 4ms/sample - loss: 0.0297 - acc: 0.9898 - val_loss: 0.1471 - val_acc: 0.9618
# Epoch 43/200
# 49900/50000 [============================>.] - ETA: 0s - loss: 0.0089 - acc: 0.9977
# Epoch 00043: val_loss did not improve from 0.11941
# 50000/50000 [==============================] - 180s 4ms/sample - loss: 0.0089 - acc: 0.9977 - val_loss: 0.1324 - val_acc: 0.9658
# Training time: 7480.0444757938385 s

# %%
model.load_weights(file_path)
model.evaluate(x_test, to_categorical(y_test))
# Out:
# 10000/10000 [==============================] - 27s 3ms/sample - loss: 0.1167 - acc: 0.9725
# [0.11669970849134843, 0.9725]
